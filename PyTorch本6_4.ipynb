# %% [markdown]
# <a href="https://colab.research.google.com/github/pea-sys/Til/blob/master/PyTorch%E6%9C%AC6_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6.4 Efficient GANの作成
# 本ファイルでは、Efficient GANのネットワークを実装し、学習をします。
#
# # 6.4 学習目標
# * Efficient GANを実装し、手書き数字画像で異常検知が生成できる
#
#
# [写経元](https://github.com/YutaroOgawa/pytorch_advanced/blob/master/6_gan_anomaly_detection/6-4_EfficientGAN.ipynb)

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  # data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
        
    # 7と8を200枚ずつ作成したらbreak
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count2+=1
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# フォルダ「data」の下にフォルダ「img_78_28size」を作成する
data_dir_path = "./data/img_78_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78_28size」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
    
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test_28size/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count2+=1 
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4322],
#         [0.4629]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # Encoderの実装

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.0669, -0.2844, -0.3601,  0.1404, -0.2922, -0.4834, -0.0025,  0.0258,
#          -0.1298, -0.2613, -0.4292, -0.2584, -0.6141, -0.1440,  0.1142,  0.2175,
#           0.0730,  0.0323, -0.7176, -0.7410],
#         [ 0.4822,  0.3682, -0.0647, -0.0773,  0.0989,  0.3012,  0.8054,  0.4399,
#           1.0848, -0.2809,  0.0619, -0.3179, -0.2963, -0.1192,  0.6562, -0.1707,
#           0.1287, -0.6156,  0.3127, -0.4819]], grad_fn=<AddmmBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習

# %%
# モデルを学習させる関数を作成


def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # 真の画像を判定　
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. Encoderの学習
            # --------------------
            # 真の画像のzを推定
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 誤差を計算
            e_loss = criterion(d_out_real.view(-1), label_fake)

            # バックプロパゲーション
            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1488 ||Epoch_G_Loss:0.0787 ||Epoch_E_Loss:0.0765
# timer:  0.6231 sec.
# -------------
# Epoch 1/1500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1449 ||Epoch_G_Loss:0.0812 ||Epoch_E_Loss:0.0781
# timer:  0.2304 sec.
# -------------
# Epoch 2/1500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1409 ||Epoch_G_Loss:0.0830 ||Epoch_E_Loss:0.0804
# timer:  0.2309 sec.
# -------------
# Epoch 3/1500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1367 ||Epoch_G_Loss:0.0850 ||Epoch_E_Loss:0.0836
# timer:  0.2220 sec.
# -------------
# Epoch 4/1500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.1336 ||Epoch_G_Loss:0.0867 ||Epoch_E_Loss:0.0854
# timer:  0.2183 sec.
# -------------
# Epoch 5/1500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.0884 ||Epoch_E_Loss:0.0870
# timer:  0.2221 sec.
# -------------
# Epoch 6/1500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.0886 ||Epoch_E_Loss:0.0913
# timer:  0.2258 sec.
# -------------
# Epoch 7/1500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.1239 ||Epoch_G_Loss:0.0913 ||Epoch_E_Loss:0.0949
# timer:  0.2329 sec.
# -------------
# Epoch 8/1500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.1228 ||Epoch_G_Loss:0.0932 ||Epoch_E_Loss:0.0945
# timer:  0.2244 sec.
# -------------
# Epoch 9/1500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.0942 ||Epoch_E_Loss:0.0970
# timer:  0.2224 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.0971 ||Epoch_E_Loss:0.1053
# timer:  0.2272 sec.
# -------------
# Epoch 11/1500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.1000 ||Epoch_E_Loss:0.1066
# timer:  0.2319 sec.
# -------------
# Epoch 12/1500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.1096 ||Epoch_G_Loss:0.1009 ||Epoch_E_Loss:0.1062
# timer:  0.2236 sec.
# -------------
# Epoch 13/1500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.1013 ||Epoch_G_Loss:0.1053 ||Epoch_E_Loss:0.1174
# timer:  0.2210 sec.
# -------------
# Epoch 14/1500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1109 ||Epoch_E_Loss:0.1218
# timer:  0.2242 sec.
# -------------
# Epoch 15/1500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0928 ||Epoch_G_Loss:0.1155 ||Epoch_E_Loss:0.1220
# timer:  0.2203 sec.
# -------------
# Epoch 16/1500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1227 ||Epoch_E_Loss:0.1297
# timer:  0.2264 sec.
# -------------
# Epoch 17/1500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.1313 ||Epoch_E_Loss:0.1422
# timer:  0.2376 sec.
# -------------
# Epoch 18/1500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.1378 ||Epoch_E_Loss:0.1466
# timer:  0.2279 sec.
# -------------
# Epoch 19/1500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0716 ||Epoch_G_Loss:0.1438 ||Epoch_E_Loss:0.1468
# timer:  0.2253 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.1526 ||Epoch_E_Loss:0.1664
# timer:  0.2328 sec.
# -------------
# Epoch 21/1500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.1602 ||Epoch_E_Loss:0.1830
# timer:  0.2260 sec.
# -------------
# Epoch 22/1500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0531 ||Epoch_G_Loss:0.1686 ||Epoch_E_Loss:0.1806
# timer:  0.2272 sec.
# -------------
# Epoch 23/1500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0506 ||Epoch_G_Loss:0.1772 ||Epoch_E_Loss:0.1827
# timer:  0.2184 sec.
# -------------
# Epoch 24/1500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.1814 ||Epoch_E_Loss:0.2002
# timer:  0.2304 sec.
# -------------
# Epoch 25/1500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0402 ||Epoch_G_Loss:0.1918 ||Epoch_E_Loss:0.2171
# timer:  0.2350 sec.
# -------------
# Epoch 26/1500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0394 ||Epoch_G_Loss:0.1993 ||Epoch_E_Loss:0.2160
# timer:  0.2241 sec.
# -------------
# Epoch 27/1500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0374 ||Epoch_G_Loss:0.2050 ||Epoch_E_Loss:0.2169
# timer:  0.2346 sec.
# -------------
# Epoch 28/1500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.2168 ||Epoch_E_Loss:0.2323
# timer:  0.2272 sec.
# -------------
# Epoch 29/1500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.2233 ||Epoch_E_Loss:0.2472
# timer:  0.2491 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0301 ||Epoch_G_Loss:0.2306 ||Epoch_E_Loss:0.2427
# timer:  0.2310 sec.
# -------------
# Epoch 31/1500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0299 ||Epoch_G_Loss:0.2374 ||Epoch_E_Loss:0.2427
# timer:  0.2234 sec.
# -------------
# Epoch 32/1500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0241 ||Epoch_G_Loss:0.2472 ||Epoch_E_Loss:0.2769
# timer:  0.2185 sec.
# -------------
# Epoch 33/1500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0210 ||Epoch_G_Loss:0.2571 ||Epoch_E_Loss:0.2970
# timer:  0.2312 sec.
# -------------
# Epoch 34/1500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0213 ||Epoch_G_Loss:0.2644 ||Epoch_E_Loss:0.2915
# timer:  0.2410 sec.
# -------------
# Epoch 35/1500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0223 ||Epoch_G_Loss:0.2686 ||Epoch_E_Loss:0.2811
# timer:  0.2283 sec.
# -------------
# Epoch 36/1500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0224 ||Epoch_G_Loss:0.2750 ||Epoch_E_Loss:0.2756
# timer:  0.2304 sec.
# -------------
# Epoch 37/1500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0218 ||Epoch_G_Loss:0.2821 ||Epoch_E_Loss:0.2768
# timer:  0.2182 sec.
# -------------
# Epoch 38/1500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0192 ||Epoch_G_Loss:0.2917 ||Epoch_E_Loss:0.2917
# timer:  0.2278 sec.
# -------------
# Epoch 39/1500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0176 ||Epoch_G_Loss:0.2992 ||Epoch_E_Loss:0.3007
# timer:  0.2234 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.3071 ||Epoch_E_Loss:0.3090
# timer:  0.2317 sec.
# -------------
# Epoch 41/1500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.3206 ||Epoch_E_Loss:0.3104
# timer:  0.2219 sec.
# -------------
# Epoch 42/1500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0144 ||Epoch_G_Loss:0.3254 ||Epoch_E_Loss:0.3157
# timer:  0.2225 sec.
# -------------
# Epoch 43/1500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0125 ||Epoch_G_Loss:0.3349 ||Epoch_E_Loss:0.3403
# timer:  0.2481 sec.
# -------------
# Epoch 44/1500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.3362 ||Epoch_E_Loss:0.3641
# timer:  0.2325 sec.
# -------------
# Epoch 45/1500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.3340 ||Epoch_E_Loss:0.3689
# timer:  0.2180 sec.
# -------------
# Epoch 46/1500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0133 ||Epoch_G_Loss:0.3305 ||Epoch_E_Loss:0.3376
# timer:  0.2183 sec.
# -------------
# Epoch 47/1500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0130 ||Epoch_G_Loss:0.3359 ||Epoch_E_Loss:0.3479
# timer:  0.2258 sec.
# -------------
# Epoch 48/1500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0118 ||Epoch_G_Loss:0.3483 ||Epoch_E_Loss:0.3651
# timer:  0.2276 sec.
# -------------
# Epoch 49/1500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.3558 ||Epoch_E_Loss:0.3653
# timer:  0.2223 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0118 ||Epoch_G_Loss:0.3666 ||Epoch_E_Loss:0.3454
# timer:  0.2232 sec.
# -------------
# Epoch 51/1500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.3768 ||Epoch_E_Loss:0.3450
# timer:  0.2181 sec.
# -------------
# Epoch 52/1500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0099 ||Epoch_G_Loss:0.3854 ||Epoch_E_Loss:0.3706
# timer:  0.2306 sec.
# -------------
# Epoch 53/1500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0101 ||Epoch_G_Loss:0.3852 ||Epoch_E_Loss:0.3596
# timer:  0.2276 sec.
# -------------
# Epoch 54/1500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.3863 ||Epoch_E_Loss:0.3456
# timer:  0.2225 sec.
# -------------
# Epoch 55/1500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0098 ||Epoch_G_Loss:0.3891 ||Epoch_E_Loss:0.3665
# timer:  0.2217 sec.
# -------------
# Epoch 56/1500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.3956 ||Epoch_E_Loss:0.3919
# timer:  0.2231 sec.
# -------------
# Epoch 57/1500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0082 ||Epoch_G_Loss:0.3900 ||Epoch_E_Loss:0.3913
# timer:  0.2299 sec.
# -------------
# Epoch 58/1500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.3944 ||Epoch_E_Loss:0.3930
# timer:  0.2196 sec.
# -------------
# Epoch 59/1500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.4033 ||Epoch_E_Loss:0.3911
# timer:  0.2312 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0072 ||Epoch_G_Loss:0.4028 ||Epoch_E_Loss:0.4065
# timer:  0.2239 sec.
# -------------
# Epoch 61/1500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4140 ||Epoch_E_Loss:0.4233
# timer:  0.2313 sec.
# -------------
# Epoch 62/1500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4135 ||Epoch_E_Loss:0.4239
# timer:  0.2187 sec.
# -------------
# Epoch 63/1500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0059 ||Epoch_G_Loss:0.4164 ||Epoch_E_Loss:0.4363
# timer:  0.2253 sec.
# -------------
# Epoch 64/1500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0056 ||Epoch_G_Loss:0.4227 ||Epoch_E_Loss:0.4414
# timer:  0.2205 sec.
# -------------
# Epoch 65/1500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.4204 ||Epoch_E_Loss:0.4280
# timer:  0.2301 sec.
# -------------
# Epoch 66/1500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0079 ||Epoch_G_Loss:0.4098 ||Epoch_E_Loss:0.3895
# timer:  0.2209 sec.
# -------------
# Epoch 67/1500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.4107 ||Epoch_E_Loss:0.4005
# timer:  0.2208 sec.
# -------------
# Epoch 68/1500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4327 ||Epoch_E_Loss:0.4372
# timer:  0.2257 sec.
# -------------
# Epoch 69/1500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0050 ||Epoch_G_Loss:0.4385 ||Epoch_E_Loss:0.4601
# timer:  0.2326 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.4479 ||Epoch_E_Loss:0.4599
# timer:  0.2351 sec.
# -------------
# Epoch 71/1500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.4445 ||Epoch_E_Loss:0.4570
# timer:  0.2307 sec.
# -------------
# Epoch 72/1500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.4461 ||Epoch_E_Loss:0.4452
# timer:  0.2293 sec.
# -------------
# Epoch 73/1500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0047 ||Epoch_G_Loss:0.4585 ||Epoch_E_Loss:0.4643
# timer:  0.2292 sec.
# -------------
# Epoch 74/1500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.4569 ||Epoch_E_Loss:0.4618
# timer:  0.2329 sec.
# -------------
# Epoch 75/1500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4472 ||Epoch_E_Loss:0.4525
# timer:  0.2208 sec.
# -------------
# Epoch 76/1500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.4248 ||Epoch_E_Loss:0.4173
# timer:  0.2234 sec.
# -------------
# Epoch 77/1500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0085 ||Epoch_G_Loss:0.4018 ||Epoch_E_Loss:0.4008
# timer:  0.2379 sec.
# -------------
# Epoch 78/1500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0095 ||Epoch_G_Loss:0.4156 ||Epoch_E_Loss:0.4102
# timer:  0.2504 sec.
# -------------
# Epoch 79/1500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.4069 ||Epoch_E_Loss:0.4237
# timer:  0.2270 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0086 ||Epoch_G_Loss:0.4116 ||Epoch_E_Loss:0.4025
# timer:  0.2222 sec.
# -------------
# Epoch 81/1500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0094 ||Epoch_G_Loss:0.4070 ||Epoch_E_Loss:0.3929
# timer:  0.2202 sec.
# -------------
# Epoch 82/1500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0101 ||Epoch_G_Loss:0.4062 ||Epoch_E_Loss:0.3914
# timer:  0.2235 sec.
# -------------
# Epoch 83/1500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0096 ||Epoch_G_Loss:0.3949 ||Epoch_E_Loss:0.3987
# timer:  0.2349 sec.
# -------------
# Epoch 84/1500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0188 ||Epoch_G_Loss:0.4041 ||Epoch_E_Loss:0.3836
# timer:  0.2391 sec.
# -------------
# Epoch 85/1500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0137 ||Epoch_G_Loss:0.3726 ||Epoch_E_Loss:0.3725
# timer:  0.2266 sec.
# -------------
# Epoch 86/1500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.3717 ||Epoch_E_Loss:0.3573
# timer:  0.2226 sec.
# -------------
# Epoch 87/1500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.3570 ||Epoch_E_Loss:0.3673
# timer:  0.2440 sec.
# -------------
# Epoch 88/1500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0214 ||Epoch_G_Loss:0.3649 ||Epoch_E_Loss:0.3282
# timer:  0.2440 sec.
# -------------
# Epoch 89/1500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0336 ||Epoch_G_Loss:0.3322 ||Epoch_E_Loss:0.3273
# timer:  0.2243 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0105 ||Epoch_G_Loss:0.4122 ||Epoch_E_Loss:0.3863
# timer:  0.2230 sec.
# -------------
# Epoch 91/1500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.3331 ||Epoch_E_Loss:0.3450
# timer:  0.2295 sec.
# -------------
# Epoch 92/1500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0167 ||Epoch_G_Loss:0.3433 ||Epoch_E_Loss:0.3489
# timer:  0.2263 sec.
# -------------
# Epoch 93/1500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0234 ||Epoch_G_Loss:0.3464 ||Epoch_E_Loss:0.3098
# timer:  0.2230 sec.
# -------------
# Epoch 94/1500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.3107 ||Epoch_E_Loss:0.3491
# timer:  0.2234 sec.
# -------------
# Epoch 95/1500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0128 ||Epoch_G_Loss:0.3540 ||Epoch_E_Loss:0.3763
# timer:  0.2201 sec.
# -------------
# Epoch 96/1500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.3422 ||Epoch_E_Loss:0.3609
# timer:  0.2298 sec.
# -------------
# Epoch 97/1500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.3371 ||Epoch_E_Loss:0.3485
# timer:  0.2305 sec.
# -------------
# Epoch 98/1500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.3424 ||Epoch_E_Loss:0.3469
# timer:  0.2280 sec.
# -------------
# Epoch 99/1500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0213 ||Epoch_G_Loss:0.3178 ||Epoch_E_Loss:0.3318
# timer:  0.2204 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0234 ||Epoch_G_Loss:0.3100 ||Epoch_E_Loss:0.3263
# timer:  0.2241 sec.
# -------------
# Epoch 101/1500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.2910 ||Epoch_E_Loss:0.3281
# timer:  0.2311 sec.
# -------------
# Epoch 102/1500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0250 ||Epoch_G_Loss:0.3097 ||Epoch_E_Loss:0.3302
# timer:  0.2180 sec.
# -------------
# Epoch 103/1500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.3317 ||Epoch_E_Loss:0.3405
# timer:  0.2214 sec.
# -------------
# Epoch 104/1500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.3152 ||Epoch_E_Loss:0.3454
# timer:  0.2231 sec.
# -------------
# Epoch 105/1500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0286 ||Epoch_G_Loss:0.3203 ||Epoch_E_Loss:0.3271
# timer:  0.2322 sec.
# -------------
# Epoch 106/1500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0275 ||Epoch_G_Loss:0.3185 ||Epoch_E_Loss:0.3408
# timer:  0.2228 sec.
# -------------
# Epoch 107/1500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.3357 ||Epoch_E_Loss:0.3424
# timer:  0.2211 sec.
# -------------
# Epoch 108/1500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0336 ||Epoch_G_Loss:0.2968 ||Epoch_E_Loss:0.3303
# timer:  0.2225 sec.
# -------------
# Epoch 109/1500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0434 ||Epoch_G_Loss:0.2697 ||Epoch_E_Loss:0.3051
# timer:  0.2289 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.2890 ||Epoch_E_Loss:0.2801
# timer:  0.2314 sec.
# -------------
# Epoch 111/1500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3057 ||Epoch_E_Loss:0.2895
# timer:  0.2261 sec.
# -------------
# Epoch 112/1500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0335 ||Epoch_G_Loss:0.2998 ||Epoch_E_Loss:0.3189
# timer:  0.2235 sec.
# -------------
# Epoch 113/1500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0381 ||Epoch_G_Loss:0.2744 ||Epoch_E_Loss:0.3143
# timer:  0.2270 sec.
# -------------
# Epoch 114/1500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0597 ||Epoch_G_Loss:0.2715 ||Epoch_E_Loss:0.2462
# timer:  0.2543 sec.
# -------------
# Epoch 115/1500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.2109 ||Epoch_E_Loss:0.2761
# timer:  0.2498 sec.
# -------------
# Epoch 116/1500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.2433 ||Epoch_E_Loss:0.2635
# timer:  0.2571 sec.
# -------------
# Epoch 117/1500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0442 ||Epoch_G_Loss:0.2491 ||Epoch_E_Loss:0.2892
# timer:  0.2481 sec.
# -------------
# Epoch 118/1500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0413 ||Epoch_G_Loss:0.2427 ||Epoch_E_Loss:0.2817
# timer:  0.2314 sec.
# -------------
# Epoch 119/1500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0455 ||Epoch_G_Loss:0.2562 ||Epoch_E_Loss:0.2766
# timer:  0.2290 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0491 ||Epoch_G_Loss:0.2256 ||Epoch_E_Loss:0.2688
# timer:  0.2225 sec.
# -------------
# Epoch 121/1500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2105 ||Epoch_E_Loss:0.2387
# timer:  0.2182 sec.
# -------------
# Epoch 122/1500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.1891 ||Epoch_E_Loss:0.2288
# timer:  0.2217 sec.
# -------------
# Epoch 123/1500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.2484 ||Epoch_E_Loss:0.2454
# timer:  0.2262 sec.
# -------------
# Epoch 124/1500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0583 ||Epoch_G_Loss:0.2330 ||Epoch_E_Loss:0.2327
# timer:  0.2230 sec.
# -------------
# Epoch 125/1500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0756 ||Epoch_G_Loss:0.1843 ||Epoch_E_Loss:0.2203
# timer:  0.2225 sec.
# -------------
# Epoch 126/1500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.1924 ||Epoch_E_Loss:0.2078
# timer:  0.2249 sec.
# -------------
# Epoch 127/1500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1730 ||Epoch_E_Loss:0.1944
# timer:  0.2227 sec.
# -------------
# Epoch 128/1500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1675 ||Epoch_E_Loss:0.1884
# timer:  0.2390 sec.
# -------------
# Epoch 129/1500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0586 ||Epoch_G_Loss:0.2081 ||Epoch_E_Loss:0.2402
# timer:  0.2226 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0571 ||Epoch_G_Loss:0.2284 ||Epoch_E_Loss:0.2486
# timer:  0.2226 sec.
# -------------
# Epoch 131/1500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.2467 ||Epoch_E_Loss:0.2331
# timer:  0.2287 sec.
# -------------
# Epoch 132/1500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.1728 ||Epoch_E_Loss:0.2165
# timer:  0.2278 sec.
# -------------
# Epoch 133/1500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0748 ||Epoch_G_Loss:0.1850 ||Epoch_E_Loss:0.2075
# timer:  0.2218 sec.
# -------------
# Epoch 134/1500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.1969 ||Epoch_E_Loss:0.2210
# timer:  0.2226 sec.
# -------------
# Epoch 135/1500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0677 ||Epoch_G_Loss:0.1964 ||Epoch_E_Loss:0.2243
# timer:  0.2249 sec.
# -------------
# Epoch 136/1500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0624 ||Epoch_G_Loss:0.2063 ||Epoch_E_Loss:0.2247
# timer:  0.2205 sec.
# -------------
# Epoch 137/1500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.2465 ||Epoch_E_Loss:0.2424
# timer:  0.2305 sec.
# -------------
# Epoch 138/1500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0426 ||Epoch_G_Loss:0.2344 ||Epoch_E_Loss:0.2662
# timer:  0.2260 sec.
# -------------
# Epoch 139/1500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0506 ||Epoch_G_Loss:0.2424 ||Epoch_E_Loss:0.2427
# timer:  0.2322 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0667 ||Epoch_G_Loss:0.2202 ||Epoch_E_Loss:0.2161
# timer:  0.2314 sec.
# -------------
# Epoch 141/1500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.1910 ||Epoch_E_Loss:0.1943
# timer:  0.2340 sec.
# -------------
# Epoch 142/1500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.1779 ||Epoch_E_Loss:0.2025
# timer:  0.2308 sec.
# -------------
# Epoch 143/1500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0593 ||Epoch_G_Loss:0.2176 ||Epoch_E_Loss:0.2313
# timer:  0.2234 sec.
# -------------
# Epoch 144/1500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0557 ||Epoch_G_Loss:0.2355 ||Epoch_E_Loss:0.2265
# timer:  0.2216 sec.
# -------------
# Epoch 145/1500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0641 ||Epoch_G_Loss:0.1958 ||Epoch_E_Loss:0.2174
# timer:  0.2238 sec.
# -------------
# Epoch 146/1500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0862 ||Epoch_G_Loss:0.1838 ||Epoch_E_Loss:0.1739
# timer:  0.2395 sec.
# -------------
# Epoch 147/1500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0907 ||Epoch_G_Loss:0.1562 ||Epoch_E_Loss:0.2073
# timer:  0.2231 sec.
# -------------
# Epoch 148/1500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0689 ||Epoch_G_Loss:0.1987 ||Epoch_E_Loss:0.2117
# timer:  0.2221 sec.
# -------------
# Epoch 149/1500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0527 ||Epoch_G_Loss:0.2047 ||Epoch_E_Loss:0.2342
# timer:  0.2311 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0547 ||Epoch_G_Loss:0.2054 ||Epoch_E_Loss:0.2216
# timer:  0.2324 sec.
# -------------
# Epoch 151/1500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0626 ||Epoch_G_Loss:0.2122 ||Epoch_E_Loss:0.2165
# timer:  0.2288 sec.
# -------------
# Epoch 152/1500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.1979 ||Epoch_E_Loss:0.2156
# timer:  0.2227 sec.
# -------------
# Epoch 153/1500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0617 ||Epoch_G_Loss:0.2018 ||Epoch_E_Loss:0.2162
# timer:  0.2319 sec.
# -------------
# Epoch 154/1500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0591 ||Epoch_G_Loss:0.2070 ||Epoch_E_Loss:0.2134
# timer:  0.2358 sec.
# -------------
# Epoch 155/1500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0656 ||Epoch_G_Loss:0.1770 ||Epoch_E_Loss:0.2034
# timer:  0.2331 sec.
# -------------
# Epoch 156/1500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0752 ||Epoch_G_Loss:0.1821 ||Epoch_E_Loss:0.1931
# timer:  0.2266 sec.
# -------------
# Epoch 157/1500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.1893 ||Epoch_E_Loss:0.2082
# timer:  0.2269 sec.
# -------------
# Epoch 158/1500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0578 ||Epoch_G_Loss:0.2257 ||Epoch_E_Loss:0.2197
# timer:  0.2249 sec.
# -------------
# Epoch 159/1500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.1980 ||Epoch_E_Loss:0.2285
# timer:  0.2466 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.1945 ||Epoch_E_Loss:0.2092
# timer:  0.2394 sec.
# -------------
# Epoch 161/1500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0756 ||Epoch_G_Loss:0.1959 ||Epoch_E_Loss:0.2084
# timer:  0.2433 sec.
# -------------
# Epoch 162/1500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.2059 ||Epoch_E_Loss:0.2025
# timer:  0.2302 sec.
# -------------
# Epoch 163/1500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0693 ||Epoch_G_Loss:0.2080 ||Epoch_E_Loss:0.2045
# timer:  0.2287 sec.
# -------------
# Epoch 164/1500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0672 ||Epoch_G_Loss:0.2053 ||Epoch_E_Loss:0.2125
# timer:  0.2359 sec.
# -------------
# Epoch 165/1500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.1960 ||Epoch_E_Loss:0.2014
# timer:  0.2325 sec.
# -------------
# Epoch 166/1500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0775 ||Epoch_G_Loss:0.1911 ||Epoch_E_Loss:0.1975
# timer:  0.2254 sec.
# -------------
# Epoch 167/1500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.1932 ||Epoch_E_Loss:0.2167
# timer:  0.2351 sec.
# -------------
# Epoch 168/1500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0709 ||Epoch_G_Loss:0.2069 ||Epoch_E_Loss:0.2106
# timer:  0.2238 sec.
# -------------
# Epoch 169/1500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.1995 ||Epoch_E_Loss:0.1986
# timer:  0.2437 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0766 ||Epoch_G_Loss:0.1944 ||Epoch_E_Loss:0.2215
# timer:  0.2332 sec.
# -------------
# Epoch 171/1500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0779 ||Epoch_G_Loss:0.1904 ||Epoch_E_Loss:0.2015
# timer:  0.2486 sec.
# -------------
# Epoch 172/1500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0696 ||Epoch_G_Loss:0.2100 ||Epoch_E_Loss:0.2099
# timer:  0.2635 sec.
# -------------
# Epoch 173/1500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0584 ||Epoch_G_Loss:0.2230 ||Epoch_E_Loss:0.2341
# timer:  0.2394 sec.
# -------------
# Epoch 174/1500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0610 ||Epoch_G_Loss:0.2162 ||Epoch_E_Loss:0.2282
# timer:  0.2472 sec.
# -------------
# Epoch 175/1500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0662 ||Epoch_G_Loss:0.2226 ||Epoch_E_Loss:0.2170
# timer:  0.2366 sec.
# -------------
# Epoch 176/1500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0772 ||Epoch_G_Loss:0.2045 ||Epoch_E_Loss:0.1933
# timer:  0.2454 sec.
# -------------
# Epoch 177/1500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.1987 ||Epoch_E_Loss:0.2030
# timer:  0.2369 sec.
# -------------
# Epoch 178/1500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.1975 ||Epoch_E_Loss:0.2103
# timer:  0.2336 sec.
# -------------
# Epoch 179/1500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0726 ||Epoch_G_Loss:0.2189 ||Epoch_E_Loss:0.1932
# timer:  0.2342 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.1951 ||Epoch_E_Loss:0.2245
# timer:  0.2265 sec.
# -------------
# Epoch 181/1500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0646 ||Epoch_G_Loss:0.2294 ||Epoch_E_Loss:0.2222
# timer:  0.2231 sec.
# -------------
# Epoch 182/1500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2179 ||Epoch_E_Loss:0.2377
# timer:  0.2396 sec.
# -------------
# Epoch 183/1500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0774 ||Epoch_G_Loss:0.2082 ||Epoch_E_Loss:0.2008
# timer:  0.2377 sec.
# -------------
# Epoch 184/1500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2052 ||Epoch_E_Loss:0.2127
# timer:  0.2388 sec.
# -------------
# Epoch 185/1500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.1828 ||Epoch_E_Loss:0.2185
# timer:  0.2338 sec.
# -------------
# Epoch 186/1500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0812 ||Epoch_G_Loss:0.2088 ||Epoch_E_Loss:0.2078
# timer:  0.2428 sec.
# -------------
# Epoch 187/1500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0760 ||Epoch_G_Loss:0.2006 ||Epoch_E_Loss:0.2170
# timer:  0.2315 sec.
# -------------
# Epoch 188/1500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0716 ||Epoch_G_Loss:0.2091 ||Epoch_E_Loss:0.2245
# timer:  0.2379 sec.
# -------------
# Epoch 189/1500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.2219 ||Epoch_E_Loss:0.2251
# timer:  0.2429 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.2018 ||Epoch_E_Loss:0.2113
# timer:  0.2332 sec.
# -------------
# Epoch 191/1500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0879 ||Epoch_G_Loss:0.2077 ||Epoch_E_Loss:0.2093
# timer:  0.2404 sec.
# -------------
# Epoch 192/1500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1963 ||Epoch_E_Loss:0.2073
# timer:  0.2411 sec.
# -------------
# Epoch 193/1500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0996 ||Epoch_G_Loss:0.1751 ||Epoch_E_Loss:0.2014
# timer:  0.2467 sec.
# -------------
# Epoch 194/1500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.1151 ||Epoch_G_Loss:0.1720 ||Epoch_E_Loss:0.1805
# timer:  0.2270 sec.
# -------------
# Epoch 195/1500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1027 ||Epoch_G_Loss:0.1858 ||Epoch_E_Loss:0.1832
# timer:  0.2282 sec.
# -------------
# Epoch 196/1500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0948 ||Epoch_G_Loss:0.1658 ||Epoch_E_Loss:0.1937
# timer:  0.2536 sec.
# -------------
# Epoch 197/1500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1862 ||Epoch_E_Loss:0.1840
# timer:  0.2305 sec.
# -------------
# Epoch 198/1500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.1724 ||Epoch_E_Loss:0.1710
# timer:  0.2509 sec.
# -------------
# Epoch 199/1500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.1229 ||Epoch_G_Loss:0.1484 ||Epoch_E_Loss:0.1717
# timer:  0.2416 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.1319 ||Epoch_E_Loss:0.1401
# timer:  0.2330 sec.
# -------------
# Epoch 201/1500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1286 ||Epoch_G_Loss:0.1425 ||Epoch_E_Loss:0.1499
# timer:  0.2375 sec.
# -------------
# Epoch 202/1500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.1062 ||Epoch_G_Loss:0.1673 ||Epoch_E_Loss:0.1668
# timer:  0.2423 sec.
# -------------
# Epoch 203/1500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.1514 ||Epoch_E_Loss:0.1716
# timer:  0.2337 sec.
# -------------
# Epoch 204/1500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1295 ||Epoch_G_Loss:0.1434 ||Epoch_E_Loss:0.1414
# timer:  0.2352 sec.
# -------------
# Epoch 205/1500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.1349 ||Epoch_G_Loss:0.1282 ||Epoch_E_Loss:0.1464
# timer:  0.2383 sec.
# -------------
# Epoch 206/1500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.1293 ||Epoch_G_Loss:0.1291 ||Epoch_E_Loss:0.1378
# timer:  0.2389 sec.
# -------------
# Epoch 207/1500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.1225 ||Epoch_G_Loss:0.1415 ||Epoch_E_Loss:0.1437
# timer:  0.2487 sec.
# -------------
# Epoch 208/1500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.1201 ||Epoch_G_Loss:0.1452 ||Epoch_E_Loss:0.1559
# timer:  0.2322 sec.
# -------------
# Epoch 209/1500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.1079 ||Epoch_G_Loss:0.1422 ||Epoch_E_Loss:0.1553
# timer:  0.2292 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.1194 ||Epoch_G_Loss:0.1380 ||Epoch_E_Loss:0.1426
# timer:  0.2258 sec.
# -------------
# Epoch 211/1500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.1448 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1307
# timer:  0.2349 sec.
# -------------
# Epoch 212/1500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.1534 ||Epoch_G_Loss:0.1094 ||Epoch_E_Loss:0.1108
# timer:  0.2311 sec.
# -------------
# Epoch 213/1500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.1308 ||Epoch_G_Loss:0.1154 ||Epoch_E_Loss:0.1233
# timer:  0.2256 sec.
# -------------
# Epoch 214/1500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.1062 ||Epoch_G_Loss:0.1295 ||Epoch_E_Loss:0.1431
# timer:  0.2226 sec.
# -------------
# Epoch 215/1500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1460 ||Epoch_E_Loss:0.1473
# timer:  0.2255 sec.
# -------------
# Epoch 216/1500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1051 ||Epoch_G_Loss:0.1264 ||Epoch_E_Loss:0.1511
# timer:  0.2323 sec.
# -------------
# Epoch 217/1500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1143 ||Epoch_E_Loss:0.1496
# timer:  0.2241 sec.
# -------------
# Epoch 218/1500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1283 ||Epoch_G_Loss:0.1234 ||Epoch_E_Loss:0.1361
# timer:  0.2221 sec.
# -------------
# Epoch 219/1500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.1492 ||Epoch_G_Loss:0.1016 ||Epoch_E_Loss:0.1213
# timer:  0.2258 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1610 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.1108
# timer:  0.2308 sec.
# -------------
# Epoch 221/1500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.1267 ||Epoch_G_Loss:0.1180 ||Epoch_E_Loss:0.1306
# timer:  0.2223 sec.
# -------------
# Epoch 222/1500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1016 ||Epoch_G_Loss:0.1421 ||Epoch_E_Loss:0.1515
# timer:  0.2208 sec.
# -------------
# Epoch 223/1500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1490
# timer:  0.2215 sec.
# -------------
# Epoch 224/1500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.1014 ||Epoch_G_Loss:0.1437 ||Epoch_E_Loss:0.1508
# timer:  0.2259 sec.
# -------------
# Epoch 225/1500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1178 ||Epoch_G_Loss:0.1277 ||Epoch_E_Loss:0.1338
# timer:  0.2231 sec.
# -------------
# Epoch 226/1500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1318 ||Epoch_E_Loss:0.1443
# timer:  0.2250 sec.
# -------------
# Epoch 227/1500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.1072 ||Epoch_G_Loss:0.1365 ||Epoch_E_Loss:0.1424
# timer:  0.2197 sec.
# -------------
# Epoch 228/1500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.1029 ||Epoch_G_Loss:0.1448 ||Epoch_E_Loss:0.1520
# timer:  0.2244 sec.
# -------------
# Epoch 229/1500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.1298 ||Epoch_G_Loss:0.1178 ||Epoch_E_Loss:0.1332
# timer:  0.2315 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1348 ||Epoch_G_Loss:0.1214 ||Epoch_E_Loss:0.1233
# timer:  0.2211 sec.
# -------------
# Epoch 231/1500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.1247 ||Epoch_G_Loss:0.1306 ||Epoch_E_Loss:0.1436
# timer:  0.2220 sec.
# -------------
# Epoch 232/1500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.1440 ||Epoch_E_Loss:0.1464
# timer:  0.2237 sec.
# -------------
# Epoch 233/1500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.1105 ||Epoch_G_Loss:0.1554 ||Epoch_E_Loss:0.1470
# timer:  0.2332 sec.
# -------------
# Epoch 234/1500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.1499 ||Epoch_E_Loss:0.1430
# timer:  0.2225 sec.
# -------------
# Epoch 235/1500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.1035 ||Epoch_G_Loss:0.1434 ||Epoch_E_Loss:0.1559
# timer:  0.2191 sec.
# -------------
# Epoch 236/1500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.1167 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1468
# timer:  0.2242 sec.
# -------------
# Epoch 237/1500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.1581 ||Epoch_G_Loss:0.1285 ||Epoch_E_Loss:0.1179
# timer:  0.2291 sec.
# -------------
# Epoch 238/1500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.1363 ||Epoch_G_Loss:0.1152 ||Epoch_E_Loss:0.1311
# timer:  0.2398 sec.
# -------------
# Epoch 239/1500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1250 ||Epoch_E_Loss:0.1461
# timer:  0.2275 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1376 ||Epoch_E_Loss:0.1325
# timer:  0.2252 sec.
# -------------
# Epoch 241/1500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.1432 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1350
# timer:  0.2330 sec.
# -------------
# Epoch 242/1500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.1184 ||Epoch_E_Loss:0.1430
# timer:  0.2617 sec.
# -------------
# Epoch 243/1500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.1506 ||Epoch_G_Loss:0.1147 ||Epoch_E_Loss:0.1318
# timer:  0.2537 sec.
# -------------
# Epoch 244/1500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.1495 ||Epoch_G_Loss:0.1122 ||Epoch_E_Loss:0.1365
# timer:  0.2542 sec.
# -------------
# Epoch 245/1500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.1463 ||Epoch_G_Loss:0.1315 ||Epoch_E_Loss:0.1365
# timer:  0.2489 sec.
# -------------
# Epoch 246/1500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1682
# timer:  0.2435 sec.
# -------------
# Epoch 247/1500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.1432 ||Epoch_E_Loss:0.1420
# timer:  0.2444 sec.
# -------------
# Epoch 248/1500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1608 ||Epoch_G_Loss:0.1023 ||Epoch_E_Loss:0.1293
# timer:  0.2550 sec.
# -------------
# Epoch 249/1500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.1442 ||Epoch_G_Loss:0.1262 ||Epoch_E_Loss:0.1392
# timer:  0.2557 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1375 ||Epoch_G_Loss:0.1327 ||Epoch_E_Loss:0.1449
# timer:  0.2639 sec.
# -------------
# Epoch 251/1500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.2237 ||Epoch_G_Loss:0.0879 ||Epoch_E_Loss:0.0952
# timer:  0.2226 sec.
# -------------
# Epoch 252/1500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.2329 ||Epoch_G_Loss:0.0720 ||Epoch_E_Loss:0.0862
# timer:  0.2219 sec.
# -------------
# Epoch 253/1500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.1506 ||Epoch_G_Loss:0.1056 ||Epoch_E_Loss:0.1283
# timer:  0.2273 sec.
# -------------
# Epoch 254/1500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.1303 ||Epoch_E_Loss:0.1472
# timer:  0.2223 sec.
# -------------
# Epoch 255/1500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.1242 ||Epoch_G_Loss:0.1316 ||Epoch_E_Loss:0.1389
# timer:  0.2300 sec.
# -------------
# Epoch 256/1500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.1216 ||Epoch_G_Loss:0.1203 ||Epoch_E_Loss:0.1383
# timer:  0.2134 sec.
# -------------
# Epoch 257/1500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.1278 ||Epoch_G_Loss:0.1161 ||Epoch_E_Loss:0.1355
# timer:  0.2167 sec.
# -------------
# Epoch 258/1500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.1552 ||Epoch_G_Loss:0.1080 ||Epoch_E_Loss:0.1200
# timer:  0.2248 sec.
# -------------
# Epoch 259/1500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.1632 ||Epoch_G_Loss:0.1101 ||Epoch_E_Loss:0.1189
# timer:  0.2269 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1548 ||Epoch_G_Loss:0.1050 ||Epoch_E_Loss:0.1214
# timer:  0.2222 sec.
# -------------
# Epoch 261/1500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.1691 ||Epoch_G_Loss:0.0968 ||Epoch_E_Loss:0.1188
# timer:  0.2211 sec.
# -------------
# Epoch 262/1500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.1493 ||Epoch_G_Loss:0.1078 ||Epoch_E_Loss:0.1354
# timer:  0.2162 sec.
# -------------
# Epoch 263/1500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.1257 ||Epoch_G_Loss:0.1227 ||Epoch_E_Loss:0.1500
# timer:  0.2206 sec.
# -------------
# Epoch 264/1500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.1438 ||Epoch_G_Loss:0.1136 ||Epoch_E_Loss:0.1335
# timer:  0.2315 sec.
# -------------
# Epoch 265/1500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.1793 ||Epoch_G_Loss:0.0942 ||Epoch_E_Loss:0.1172
# timer:  0.2222 sec.
# -------------
# Epoch 266/1500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.1561 ||Epoch_G_Loss:0.1111 ||Epoch_E_Loss:0.1275
# timer:  0.2224 sec.
# -------------
# Epoch 267/1500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.1421 ||Epoch_G_Loss:0.1065 ||Epoch_E_Loss:0.1365
# timer:  0.2299 sec.
# -------------
# Epoch 268/1500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.1645 ||Epoch_G_Loss:0.1015 ||Epoch_E_Loss:0.1212
# timer:  0.2399 sec.
# -------------
# Epoch 269/1500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.1799 ||Epoch_G_Loss:0.0882 ||Epoch_E_Loss:0.1117
# timer:  0.2382 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1763 ||Epoch_G_Loss:0.0917 ||Epoch_E_Loss:0.1129
# timer:  0.2309 sec.
# -------------
# Epoch 271/1500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.1694 ||Epoch_G_Loss:0.0985 ||Epoch_E_Loss:0.1144
# timer:  0.2178 sec.
# -------------
# Epoch 272/1500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.1489 ||Epoch_G_Loss:0.1027 ||Epoch_E_Loss:0.1250
# timer:  0.2256 sec.
# -------------
# Epoch 273/1500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.1633 ||Epoch_G_Loss:0.0956 ||Epoch_E_Loss:0.1164
# timer:  0.2332 sec.
# -------------
# Epoch 274/1500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.1595 ||Epoch_G_Loss:0.0947 ||Epoch_E_Loss:0.1207
# timer:  0.2336 sec.
# -------------
# Epoch 275/1500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.1401 ||Epoch_G_Loss:0.1066 ||Epoch_E_Loss:0.1278
# timer:  0.2540 sec.
# -------------
# Epoch 276/1500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.1273 ||Epoch_G_Loss:0.1248 ||Epoch_E_Loss:0.1323
# timer:  0.2537 sec.
# -------------
# Epoch 277/1500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.1345 ||Epoch_G_Loss:0.1104 ||Epoch_E_Loss:0.1253
# timer:  0.2605 sec.
# -------------
# Epoch 278/1500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1591 ||Epoch_G_Loss:0.0894 ||Epoch_E_Loss:0.1127
# timer:  0.2674 sec.
# -------------
# Epoch 279/1500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.1704 ||Epoch_G_Loss:0.0914 ||Epoch_E_Loss:0.1051
# timer:  0.2334 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1461 ||Epoch_G_Loss:0.0921 ||Epoch_E_Loss:0.1191
# timer:  0.2256 sec.
# -------------
# Epoch 281/1500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.1302 ||Epoch_G_Loss:0.1086 ||Epoch_E_Loss:0.1311
# timer:  0.2317 sec.
# -------------
# Epoch 282/1500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.1210 ||Epoch_G_Loss:0.1287 ||Epoch_E_Loss:0.1310
# timer:  0.2334 sec.
# -------------
# Epoch 283/1500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.1297 ||Epoch_G_Loss:0.1091 ||Epoch_E_Loss:0.1304
# timer:  0.2358 sec.
# -------------
# Epoch 284/1500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.1049 ||Epoch_E_Loss:0.1278
# timer:  0.2263 sec.
# -------------
# Epoch 285/1500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1292 ||Epoch_E_Loss:0.1418
# timer:  0.2334 sec.
# -------------
# Epoch 286/1500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.1268 ||Epoch_E_Loss:0.1509
# timer:  0.2393 sec.
# -------------
# Epoch 287/1500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.1619 ||Epoch_G_Loss:0.0993 ||Epoch_E_Loss:0.1180
# timer:  0.2328 sec.
# -------------
# Epoch 288/1500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.1771 ||Epoch_G_Loss:0.0900 ||Epoch_E_Loss:0.1109
# timer:  0.2400 sec.
# -------------
# Epoch 289/1500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.1634 ||Epoch_G_Loss:0.0854 ||Epoch_E_Loss:0.1183
# timer:  0.2383 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1461 ||Epoch_G_Loss:0.1149 ||Epoch_E_Loss:0.1231
# timer:  0.2381 sec.
# -------------
# Epoch 291/1500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.1449 ||Epoch_G_Loss:0.1061 ||Epoch_E_Loss:0.1258
# timer:  0.2318 sec.
# -------------
# Epoch 292/1500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.1634 ||Epoch_G_Loss:0.1088 ||Epoch_E_Loss:0.1140
# timer:  0.2449 sec.
# -------------
# Epoch 293/1500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.1423 ||Epoch_G_Loss:0.1210 ||Epoch_E_Loss:0.1212
# timer:  0.2386 sec.
# -------------
# Epoch 294/1500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.1269 ||Epoch_G_Loss:0.1230 ||Epoch_E_Loss:0.1285
# timer:  0.2393 sec.
# -------------
# Epoch 295/1500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.1558 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1162
# timer:  0.2314 sec.
# -------------
# Epoch 296/1500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.1511 ||Epoch_G_Loss:0.1106 ||Epoch_E_Loss:0.1170
# timer:  0.2424 sec.
# -------------
# Epoch 297/1500
# -------------
# （train）
# -------------
# ...
# timer:  0.2182 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1508 ||Epoch_E_Loss:0.1536
# timer:  0.2310 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1432 ||Epoch_E_Loss:0.1569
# timer:  0.2314 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1331 ||Epoch_E_Loss:0.1548
# timer:  0.2185 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.0966 ||Epoch_G_Loss:0.1588 ||Epoch_E_Loss:0.1522
# timer:  0.2212 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.0900 ||Epoch_G_Loss:0.1517 ||Epoch_E_Loss:0.1533
# timer:  0.2217 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1420 ||Epoch_E_Loss:0.1555
# timer:  0.2180 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1470 ||Epoch_E_Loss:0.1453
# timer:  0.2220 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1418 ||Epoch_E_Loss:0.1442
# timer:  0.2240 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.1294 ||Epoch_E_Loss:0.1486
# timer:  0.2205 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.1102 ||Epoch_G_Loss:0.1265 ||Epoch_E_Loss:0.1422
# timer:  0.2214 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.0966 ||Epoch_G_Loss:0.1478 ||Epoch_E_Loss:0.1534
# timer:  0.2155 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1513 ||Epoch_E_Loss:0.1521
# timer:  0.2146 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.0792 ||Epoch_G_Loss:0.1674 ||Epoch_E_Loss:0.1636
# timer:  0.2230 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.0840 ||Epoch_G_Loss:0.1657 ||Epoch_E_Loss:0.1637
# timer:  0.2174 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1395 ||Epoch_E_Loss:0.1701
# timer:  0.2172 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.0971 ||Epoch_G_Loss:0.1615 ||Epoch_E_Loss:0.1468
# timer:  0.2212 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1403 ||Epoch_E_Loss:0.1586
# timer:  0.2176 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1468 ||Epoch_E_Loss:0.1526
# timer:  0.2237 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1437 ||Epoch_E_Loss:0.1493
# timer:  0.2178 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.1280 ||Epoch_G_Loss:0.1030 ||Epoch_E_Loss:0.1477
# timer:  0.2195 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.1391 ||Epoch_G_Loss:0.1289 ||Epoch_E_Loss:0.1535
# timer:  0.2171 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.0856 ||Epoch_G_Loss:0.1480 ||Epoch_E_Loss:0.1895
# timer:  0.2213 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1235 ||Epoch_E_Loss:0.1635
# timer:  0.2124 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.1416 ||Epoch_G_Loss:0.1069 ||Epoch_E_Loss:0.1329
# timer:  0.2177 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.1302 ||Epoch_G_Loss:0.1125 ||Epoch_E_Loss:0.1373
# timer:  0.2153 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.1028 ||Epoch_G_Loss:0.1299 ||Epoch_E_Loss:0.1486
# timer:  0.2194 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.0849 ||Epoch_G_Loss:0.1560 ||Epoch_E_Loss:0.1615
# timer:  0.2252 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1466 ||Epoch_E_Loss:0.1588
# timer:  0.2205 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1470 ||Epoch_E_Loss:0.1472
# timer:  0.2516 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.0932 ||Epoch_G_Loss:0.1369 ||Epoch_E_Loss:0.1587
# timer:  0.2495 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.0932 ||Epoch_G_Loss:0.1494 ||Epoch_E_Loss:0.1488
# timer:  0.2600 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1523 ||Epoch_E_Loss:0.1494
# timer:  0.2399 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.1435 ||Epoch_E_Loss:0.1553
# timer:  0.2238 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.1355 ||Epoch_E_Loss:0.1619
# timer:  0.2164 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1494 ||Epoch_E_Loss:0.1415
# timer:  0.2169 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.1418 ||Epoch_E_Loss:0.1480
# timer:  0.2151 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1232 ||Epoch_E_Loss:0.1531
# timer:  0.2201 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.0984 ||Epoch_G_Loss:0.1462 ||Epoch_E_Loss:0.1466
# timer:  0.2164 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.1528 ||Epoch_E_Loss:0.1528
# timer:  0.2206 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.1604 ||Epoch_E_Loss:0.1674
# timer:  0.2230 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.0765 ||Epoch_G_Loss:0.1515 ||Epoch_E_Loss:0.1688
# timer:  0.2186 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1654 ||Epoch_E_Loss:0.1452
# timer:  0.2153 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.1346 ||Epoch_E_Loss:0.1577
# timer:  0.2248 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.0897 ||Epoch_G_Loss:0.1384 ||Epoch_E_Loss:0.1549
# timer:  0.2190 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.0878 ||Epoch_G_Loss:0.1467 ||Epoch_E_Loss:0.1582
# timer:  0.2192 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1523 ||Epoch_E_Loss:0.1541
# timer:  0.2139 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.1403 ||Epoch_E_Loss:0.1597
# timer:  0.2130 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.0906 ||Epoch_G_Loss:0.1474 ||Epoch_E_Loss:0.1589
# timer:  0.2207 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.1476 ||Epoch_E_Loss:0.1655
# timer:  0.2168 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.1003 ||Epoch_G_Loss:0.1527 ||Epoch_E_Loss:0.1406
# timer:  0.2191 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.0984 ||Epoch_G_Loss:0.1369 ||Epoch_E_Loss:0.1652
# timer:  0.2171 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1465 ||Epoch_E_Loss:0.1437
# timer:  0.2148 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1506 ||Epoch_E_Loss:0.1589
# timer:  0.2147 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.0937 ||Epoch_G_Loss:0.1578 ||Epoch_E_Loss:0.1436
# timer:  0.2291 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.0832 ||Epoch_G_Loss:0.1544 ||Epoch_E_Loss:0.1583
# timer:  0.2154 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.1571 ||Epoch_E_Loss:0.1452
# timer:  0.2200 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1516 ||Epoch_E_Loss:0.1586
# timer:  0.2188 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1427 ||Epoch_E_Loss:0.1620
# timer:  0.2166 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.0860 ||Epoch_G_Loss:0.1704 ||Epoch_E_Loss:0.1492
# timer:  0.2218 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.1617 ||Epoch_E_Loss:0.1695
# timer:  0.2159 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.0914 ||Epoch_G_Loss:0.1575 ||Epoch_E_Loss:0.1496
# timer:  0.2204 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.0845 ||Epoch_G_Loss:0.1332 ||Epoch_E_Loss:0.1575
# timer:  0.2181 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1531 ||Epoch_E_Loss:0.1477
# timer:  0.2116 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1333 ||Epoch_E_Loss:0.1605
# timer:  0.2221 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1460 ||Epoch_E_Loss:0.1581
# timer:  0.2196 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.0817 ||Epoch_G_Loss:0.1508 ||Epoch_E_Loss:0.1708
# timer:  0.2185 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.0825 ||Epoch_G_Loss:0.1612 ||Epoch_E_Loss:0.1603
# timer:  0.2216 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1728 ||Epoch_E_Loss:0.1576
# timer:  0.2218 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.1400 ||Epoch_E_Loss:0.1717
# timer:  0.2198 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1399 ||Epoch_E_Loss:0.1528
# timer:  0.2267 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1501 ||Epoch_E_Loss:0.1421
# timer:  0.2243 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.0914 ||Epoch_G_Loss:0.1391 ||Epoch_E_Loss:0.1512
# timer:  0.2181 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1359 ||Epoch_E_Loss:0.1623
# timer:  0.2265 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.0849 ||Epoch_G_Loss:0.1677 ||Epoch_E_Loss:0.1586
# timer:  0.2217 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1598 ||Epoch_E_Loss:0.1786
# timer:  0.2205 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.1568 ||Epoch_E_Loss:0.1534
# timer:  0.2313 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.1254 ||Epoch_E_Loss:0.1534
# timer:  0.2362 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.1043 ||Epoch_G_Loss:0.1572 ||Epoch_E_Loss:0.1335
# timer:  0.2202 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.0879 ||Epoch_G_Loss:0.1475 ||Epoch_E_Loss:0.1764
# timer:  0.2122 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.0803 ||Epoch_G_Loss:0.1531 ||Epoch_E_Loss:0.1664
# timer:  0.2169 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1501 ||Epoch_E_Loss:0.1647
# timer:  0.2357 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1586 ||Epoch_E_Loss:0.1479
# timer:  0.2274 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0970 ||Epoch_G_Loss:0.1461 ||Epoch_E_Loss:0.1447
# timer:  0.2169 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1376 ||Epoch_E_Loss:0.1523
# timer:  0.2116 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1400 ||Epoch_E_Loss:0.1589
# timer:  0.2151 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.1777 ||Epoch_E_Loss:0.1487
# timer:  0.2186 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1552 ||Epoch_E_Loss:0.1716
# timer:  0.2295 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.1619 ||Epoch_E_Loss:0.1626
# timer:  0.2177 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1445 ||Epoch_E_Loss:0.1540
# timer:  0.2135 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1496 ||Epoch_E_Loss:0.1644
# timer:  0.2141 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.0801 ||Epoch_G_Loss:0.1598 ||Epoch_E_Loss:0.1744
# timer:  0.2375 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1705 ||Epoch_E_Loss:0.1667
# timer:  0.2193 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.1055 ||Epoch_G_Loss:0.1511 ||Epoch_E_Loss:0.1428
# timer:  0.2269 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.1052 ||Epoch_G_Loss:0.1508 ||Epoch_E_Loss:0.1459
# timer:  0.2139 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1502 ||Epoch_E_Loss:0.1713
# timer:  0.2169 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1510 ||Epoch_E_Loss:0.1660
# timer:  0.2228 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1483 ||Epoch_E_Loss:0.1495
# timer:  0.2174 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [184. 236. 320. 265. 165.]
