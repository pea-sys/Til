# %% [markdown]
# <a href="https://colab.research.google.com/github/pea-sys/Til/blob/master/PyTorch%E6%9C%AC2_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2.7 学習と検証の実施
# 本ファイルでは、SSDの学習と検証の実施を行います。
# [写経元](https://github.com/YutaroOgawa/pytorch_advanced/blob/master/2_objectdetection/2-7_SSD_training.ipynb)

# %%
# !git clone https://github.com/YutaroOgawa/pytorch_advanced.git
# Out:
# Cloning into 'pytorch_advanced'...
# remote: Enumerating objects: 441, done.
# remote: Total 441 (delta 0), reused 0 (delta 0), pack-reused 441
# Receiving objects: 100% (441/441), 14.62 MiB | 36.17 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# %cd pytorch_advanced/
# %cd 2_objectdetection/
# Out:
# /content/pytorch_advanced
# /content/pytorch_advanced/2_objectdetection

# %%
# パッケージのimport
import os.path as osp
import random
import time

import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)
# Out:
# 使用デバイス： cuda:0

# %% [markdown]
# # DatasetとDataLoaderを作成する

# %%
import os
import urllib.request
import zipfile
import tarfile

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# フォルダ「weights」が存在しない場合は作成する
weights_dir = "./weights/"
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

# %%
# VOC2012のデータセットをここからダウンロードします
# 時間がかかります（約15分）
url = "http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar"
target_path = os.path.join(data_dir, "VOCtrainval_11-May-2012.tar") 

if not os.path.exists(target_path):
    urllib.request.urlretrieve(url, target_path)
    
    tar = tarfile.TarFile(target_path)  # tarファイルを読み込み
    tar.extractall(data_dir)  # tarを解凍
    tar.close()  # tarファイルをクローズ

# %%
# 学習済みのSSD用のVGGのパラメータをフォルダ「weights」にダウンロード
# MIT License
# Copyright (c) 2017 Max deGroot, Ellis Brown
# https://github.com/amdegroot/ssd.pytorch
    
url = "https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth"
target_path = os.path.join(weights_dir, "vgg16_reducedfc.pth") 

if not os.path.exists(target_path):
  urllib.request.urlretrieve(url, target_path)

# %%
from utils.ssd_model import make_datapath_list, VOCDataset, DataTransform, Anno_xml2list, od_collate_fn


# ファイルパスのリストを取得
rootpath = "./data/VOCdevkit/VOC2012/"
train_img_list, train_anno_list, val_img_list, val_anno_list = make_datapath_list(
    rootpath)

# Datasetを作成
voc_classes = ['aeroplane', 'bicycle', 'bird', 'boat',
               'bottle', 'bus', 'car', 'cat', 'chair',
               'cow', 'diningtable', 'dog', 'horse',
               'motorbike', 'person', 'pottedplant',
               'sheep', 'sofa', 'train', 'tvmonitor']
color_mean = (104, 117, 123)  # (BGR)の色の平均値
input_size = 300  # 画像のinputサイズを300×300にする

train_dataset = VOCDataset(train_img_list, train_anno_list, phase="train", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

val_dataset = VOCDataset(val_img_list, val_anno_list, phase="val", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))


# DataLoaderを作成する
batch_size = 32

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, collate_fn=od_collate_fn)

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %% [markdown]
# # ネットワークモデルの作成する

# %%
from utils.ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDネットワークモデル
net = SSD(phase="train", cfg=ssd_cfg)

# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
vgg_weights = torch.load('./weights/vgg16_reducedfc.pth')
net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
net.extras.apply(weights_init)
net.loc.apply(weights_init)
net.conf.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# 使用デバイス： cuda:0
# ネットワーク設定完了：学習済みの重みをロードしました

# %% [markdown]
# # 損失関数と最適化手法を定義する

# %%
from utils.ssd_model import MultiBoxLoss

# 損失関数の設定
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD(net.parameters(), lr=1e-3,
                      momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# # 学習・検証を実施する

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # イテレーションカウンタをセット
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードに
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)

                    # 損失の計算
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()  # 勾配の計算

                        # 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # パラメータ更新

                        if (iteration % 10 == 0):  # 10iterに1度、lossを表示
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('イテレーション {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/ssd300_' +
                       str(epoch+1) + '.pth')

# %%
# 学習・検証を実行する
num_epochs= 50  
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/50
# -------------
# （train）
# イテレーション 10 || Loss: 15.3642 || 10iter: 28.0526 sec.
# イテレーション 20 || Loss: 15.1082 || 10iter: 14.6551 sec.
# イテレーション 30 || Loss: 11.7550 || 10iter: 14.4584 sec.
# イテレーション 40 || Loss: 10.1658 || 10iter: 14.5202 sec.
# イテレーション 50 || Loss: 9.0858 || 10iter: 14.9462 sec.
# イテレーション 60 || Loss: 8.4833 || 10iter: 14.7460 sec.
# イテレーション 70 || Loss: 8.3712 || 10iter: 14.8921 sec.
# イテレーション 80 || Loss: 8.4175 || 10iter: 14.7001 sec.
# イテレーション 90 || Loss: 8.7714 || 10iter: 14.9079 sec.
# イテレーション 100 || Loss: 8.1195 || 10iter: 14.8550 sec.
# イテレーション 110 || Loss: 7.9651 || 10iter: 14.5854 sec.
# イテレーション 120 || Loss: 8.8687 || 10iter: 14.6556 sec.
# イテレーション 130 || Loss: 8.8431 || 10iter: 15.1915 sec.
# イテレーション 140 || Loss: 8.3836 || 10iter: 15.2598 sec.
# イテレーション 150 || Loss: 7.9765 || 10iter: 14.9584 sec.
# イテレーション 160 || Loss: 8.7563 || 10iter: 15.1326 sec.
# イテレーション 170 || Loss: 8.1636 || 10iter: 15.1625 sec.
# -------------
# epoch 1 || Epoch_TRAIN_Loss:1748.6163 ||Epoch_VAL_Loss:0.0000
# timer:  300.6325 sec.
# -------------
# Epoch 2/50
# -------------
# （train）
# イテレーション 180 || Loss: 7.7730 || 10iter: 0.9578 sec.
# イテレーション 190 || Loss: 7.7604 || 10iter: 15.4006 sec.
# イテレーション 200 || Loss: 7.5925 || 10iter: 15.3370 sec.
# イテレーション 210 || Loss: 8.2178 || 10iter: 15.5175 sec.
# イテレーション 990 || Loss: 5.7842 || 10iter: 14.9499 sec.
# イテレーション 1000 || Loss: 6.3965 || 10iter: 14.9815 sec.
# イテレーション 1010 || Loss: 5.7971 || 10iter: 15.0864 sec.
# イテレーション 1020 || Loss: 5.8042 || 10iter: 14.8636 sec.
# イテレーション 1030 || Loss: 6.2208 || 10iter: 15.1207 sec.
# イテレーション 1040 || Loss: 5.8715 || 10iter: 14.6599 sec.
# イテレーション 1050 || Loss: 6.3258 || 10iter: 14.7954 sec.
# イテレーション 1060 || Loss: 5.4477 || 10iter: 15.0409 sec.
# イテレーション 1070 || Loss: 6.0023 || 10iter: 14.8777 sec.
# -------------
# epoch 6 || Epoch_TRAIN_Loss:1073.6722 ||Epoch_VAL_Loss:0.0000
# timer:  277.7813 sec.
# -------------
# Epoch 7/50
# -------------
# （train）
# イテレーション 1080 || Loss: 6.0258 || 10iter: 8.5995 sec.
# イテレーション 1090 || Loss: 5.5293 || 10iter: 14.8455 sec.
# イテレーション 1100 || Loss: 6.2341 || 10iter: 15.0438 sec.
# イテレーション 1110 || Loss: 6.1131 || 10iter: 14.9415 sec.
# イテレーション 1120 || Loss: 6.1845 || 10iter: 15.2766 sec.
# イテレーション 1130 || Loss: 5.8801 || 10iter: 14.9496 sec.
# イテレーション 1140 || Loss: 5.7130 || 10iter: 14.9366 sec.
# イテレーション 1150 || Loss: 6.1389 || 10iter: 15.1154 sec.
# イテレーション 1160 || Loss: 5.4714 || 10iter: 14.9486 sec.
# イテレーション 1170 || Loss: 5.8271 || 10iter: 14.8705 sec.
# イテレーション 1180 || Loss: 5.6910 || 10iter: 14.8581 sec.
# イテレーション 1190 || Loss: 5.9000 || 10iter: 14.7097 sec.
# イテレーション 1200 || Loss: 5.6768 || 10iter: 14.7148 sec.
# イテレーション 1210 || Loss: 6.0675 || 10iter: 15.0517 sec.
# イテレーション 1220 || Loss: 5.8833 || 10iter: 14.8524 sec.
# イテレーション 1230 || Loss: 6.4083 || 10iter: 14.8879 sec.
# イテレーション 1240 || Loss: 5.4621 || 10iter: 15.0548 sec.
# イテレーション 1250 || Loss: 5.4561 || 10iter: 15.0134 sec.
# -------------
# epoch 7 || Epoch_TRAIN_Loss:1037.5151 ||Epoch_VAL_Loss:0.0000
# timer:  278.7121 sec.
# -------------
# Epoch 8/50
# -------------
# （train）
# イテレーション 1260 || Loss: 5.6621 || 10iter: 10.0761 sec.
# イテレーション 1270 || Loss: 5.6128 || 10iter: 14.8460 sec.
# イテレーション 1280 || Loss: 5.9604 || 10iter: 15.0133 sec.
# イテレーション 1290 || Loss: 5.5370 || 10iter: 14.8815 sec.
# イテレーション 1300 || Loss: 6.0121 || 10iter: 14.6103 sec.
# イテレーション 1310 || Loss: 5.1104 || 10iter: 14.8692 sec.
# イテレーション 1320 || Loss: 5.9171 || 10iter: 15.1138 sec.
# イテレーション 1330 || Loss: 5.6051 || 10iter: 14.9919 sec.
# イテレーション 1340 || Loss: 6.1942 || 10iter: 15.0755 sec.
# イテレーション 1350 || Loss: 5.5076 || 10iter: 14.7657 sec.
# イテレーション 2470 || Loss: 4.6606 || 10iter: 14.8509 sec.
# イテレーション 2480 || Loss: 4.5456 || 10iter: 15.0553 sec.
# イテレーション 2490 || Loss: 4.7918 || 10iter: 15.0677 sec.
# イテレーション 2500 || Loss: 4.6226 || 10iter: 14.8638 sec.
# -------------
# epoch 14 || Epoch_TRAIN_Loss:878.4121 ||Epoch_VAL_Loss:0.0000
# timer:  278.6568 sec.
# -------------
# Epoch 15/50
# -------------
# （train）
# イテレーション 2510 || Loss: 5.3082 || 10iter: 5.5534 sec.
# イテレーション 2520 || Loss: 4.6979 || 10iter: 15.0607 sec.
# イテレーション 2530 || Loss: 4.3238 || 10iter: 14.8071 sec.
# イテレーション 2540 || Loss: 4.6269 || 10iter: 14.9191 sec.
# イテレーション 2550 || Loss: 5.1081 || 10iter: 14.8566 sec.
# イテレーション 2560 || Loss: 5.1988 || 10iter: 15.1036 sec.
# イテレーション 2570 || Loss: 4.4680 || 10iter: 14.7730 sec.
# イテレーション 2580 || Loss: 4.7274 || 10iter: 14.8130 sec.
# イテレーション 2590 || Loss: 4.8733 || 10iter: 15.1997 sec.
# イテレーション 2600 || Loss: 4.9045 || 10iter: 14.9327 sec.
# イテレーション 2610 || Loss: 5.1965 || 10iter: 14.7519 sec.
# イテレーション 2620 || Loss: 4.8466 || 10iter: 15.0767 sec.
# イテレーション 2630 || Loss: 4.2542 || 10iter: 14.9223 sec.
# イテレーション 2640 || Loss: 4.5797 || 10iter: 14.7336 sec.
# イテレーション 2650 || Loss: 4.9000 || 10iter: 14.9130 sec.
# イテレーション 2660 || Loss: 4.9398 || 10iter: 14.9977 sec.
# イテレーション 2670 || Loss: 4.8497 || 10iter: 14.7923 sec.
# イテレーション 2680 || Loss: 4.4188 || 10iter: 14.9875 sec.
# -------------
# epoch 15 || Epoch_TRAIN_Loss:857.0638 ||Epoch_VAL_Loss:0.0000
# timer:  278.3061 sec.
# -------------
# Epoch 16/50
# -------------
# （train）
# イテレーション 2690 || Loss: 4.8577 || 10iter: 7.1674 sec.
# イテレーション 2700 || Loss: 5.5615 || 10iter: 15.0251 sec.
# イテレーション 2710 || Loss: 5.0456 || 10iter: 14.9044 sec.
# イテレーション 2720 || Loss: 5.0396 || 10iter: 14.8989 sec.
# イテレーション 2730 || Loss: 4.9396 || 10iter: 14.8940 sec.
# イテレーション 2740 || Loss: 4.9050 || 10iter: 15.0879 sec.
# イテレーション 2750 || Loss: 5.0345 || 10iter: 15.0825 sec.
# イテレーション 2760 || Loss: 4.4214 || 10iter: 14.9845 sec.
# イテレーション 2770 || Loss: 5.4635 || 10iter: 15.1878 sec.
# イテレーション 2780 || Loss: 5.0850 || 10iter: 14.8601 sec.
# イテレーション 2790 || Loss: 5.3698 || 10iter: 14.8408 sec.
# イテレーション 2800 || Loss: 5.0057 || 10iter: 14.9773 sec.
# イテレーション 2810 || Loss: 5.0928 || 10iter: 14.7139 sec.
# イテレーション 2820 || Loss: 4.5889 || 10iter: 14.8276 sec.
# イテレーション 2830 || Loss: 4.3662 || 10iter: 14.9354 sec.
# イテレーション 2840 || Loss: 4.6977 || 10iter: 14.9656 sec.
# イテレーション 2850 || Loss: 4.5327 || 10iter: 15.0317 sec.
# イテレーション 2860 || Loss: 4.7839 || 10iter: 15.0203 sec.
# -------------
# epoch 16 || Epoch_TRAIN_Loss:843.4506 ||Epoch_VAL_Loss:0.0000
# timer:  278.8488 sec.
# -------------
# Epoch 17/50
# -------------
# （train）
# イテレーション 2870 || Loss: 4.2157 || 10iter: 8.6990 sec.
# イテレーション 2880 || Loss: 4.3369 || 10iter: 15.0011 sec.
# イテレーション 2890 || Loss: 4.4977 || 10iter: 15.0487 sec.
# イテレーション 2900 || Loss: 5.2251 || 10iter: 14.8102 sec.
# イテレーション 2910 || Loss: 4.8214 || 10iter: 14.9797 sec.
# イテレーション 2920 || Loss: 4.3488 || 10iter: 14.8422 sec.
# イテレーション 2930 || Loss: 4.5310 || 10iter: 14.9365 sec.
# イテレーション 2940 || Loss: 4.6008 || 10iter: 14.9108 sec.
# イテレーション 2950 || Loss: 4.9718 || 10iter: 14.9668 sec.
# イテレーション 2960 || Loss: 4.3203 || 10iter: 14.7269 sec.
# イテレーション 2970 || Loss: 4.6516 || 10iter: 14.7623 sec.
# イテレーション 2980 || Loss: 4.5704 || 10iter: 14.9862 sec.
# イテレーション 2990 || Loss: 4.3191 || 10iter: 14.9833 sec.
# イテレーション 3000 || Loss: 5.2000 || 10iter: 14.8183 sec.
# イテレーション 3010 || Loss: 4.4346 || 10iter: 14.9486 sec.
# イテレーション 3020 || Loss: 5.1240 || 10iter: 14.9727 sec.
# イテレーション 3030 || Loss: 4.2175 || 10iter: 14.5242 sec.
# イテレーション 3040 || Loss: 5.0497 || 10iter: 14.7871 sec.
# -------------
# epoch 17 || Epoch_TRAIN_Loss:825.2266 ||Epoch_VAL_Loss:0.0000
# timer:  277.6877 sec.
# -------------
# Epoch 18/50
# -------------
# （train）
# イテレーション 3050 || Loss: 4.2598 || 10iter: 9.9952 sec.
# イテレーション 3060 || Loss: 4.5080 || 10iter: 15.0085 sec.
# イテレーション 3070 || Loss: 4.3564 || 10iter: 14.8958 sec.
# イテレーション 3080 || Loss: 4.9735 || 10iter: 14.5999 sec.
# イテレーション 3090 || Loss: 4.6465 || 10iter: 14.8756 sec.
# イテレーション 3100 || Loss: 4.5543 || 10iter: 15.0542 sec.
# イテレーション 3110 || Loss: 4.7689 || 10iter: 14.9090 sec.
# イテレーション 3120 || Loss: 4.1891 || 10iter: 14.8478 sec.
# イテレーション 3130 || Loss: 5.1125 || 10iter: 14.9946 sec.
# イテレーション 3140 || Loss: 4.8205 || 10iter: 14.6261 sec.
# イテレーション 3150 || Loss: 4.6511 || 10iter: 14.9874 sec.
# イテレーション 3160 || Loss: 4.6160 || 10iter: 15.0134 sec.
# イテレーション 3170 || Loss: 4.3147 || 10iter: 14.9033 sec.
# イテレーション 3180 || Loss: 4.9841 || 10iter: 14.7558 sec.
# イテレーション 3190 || Loss: 4.1969 || 10iter: 14.7036 sec.
# イテレーション 3200 || Loss: 4.8863 || 10iter: 14.8688 sec.
# イテレーション 3210 || Loss: 4.3048 || 10iter: 14.7603 sec.
# （val）
# -------------
# epoch 20 || Epoch_TRAIN_Loss:790.3475 ||Epoch_VAL_Loss:814.2764
# timer:  399.5516 sec.
# -------------
# Epoch 21/50
# -------------
# （train）
# イテレーション 3590 || Loss: 4.2778 || 10iter: 15.5431 sec.
# イテレーション 3600 || Loss: 4.7888 || 10iter: 15.4107 sec.
# イテレーション 3610 || Loss: 4.3200 || 10iter: 15.3573 sec.
# イテレーション 3620 || Loss: 4.0159 || 10iter: 15.2523 sec.
# イテレーション 3630 || Loss: 4.6425 || 10iter: 15.0065 sec.
# イテレーション 3640 || Loss: 4.5439 || 10iter: 15.0971 sec.
# イテレーション 3650 || Loss: 4.4525 || 10iter: 15.0893 sec.
# イテレーション 3660 || Loss: 3.9838 || 10iter: 15.1749 sec.
# イテレーション 3670 || Loss: 4.4567 || 10iter: 15.1775 sec.
# イテレーション 3680 || Loss: 4.2404 || 10iter: 15.0076 sec.
# イテレーション 3690 || Loss: 4.6002 || 10iter: 15.4100 sec.
# イテレーション 3700 || Loss: 4.1013 || 10iter: 15.3173 sec.
# イテレーション 3710 || Loss: 3.9822 || 10iter: 15.8571 sec.
# イテレーション 3720 || Loss: 3.7970 || 10iter: 15.5429 sec.
# イテレーション 3730 || Loss: 4.1420 || 10iter: 15.8947 sec.
# イテレーション 3740 || Loss: 4.0452 || 10iter: 15.4522 sec.
# イテレーション 3750 || Loss: 4.3181 || 10iter: 15.3561 sec.
# -------------
# epoch 21 || Epoch_TRAIN_Loss:781.0827 ||Epoch_VAL_Loss:0.0000
# timer:  285.7729 sec.
# -------------
# Epoch 22/50
# -------------
# （train）
# イテレーション 3760 || Loss: 3.9281 || 10iter: 0.9351 sec.
# イテレーション 3770 || Loss: 3.9088 || 10iter: 15.2815 sec.
# イテレーション 3780 || Loss: 4.6494 || 10iter: 15.3597 sec.
# イテレーション 3790 || Loss: 3.8012 || 10iter: 15.5080 sec.
# イテレーション 3800 || Loss: 4.6762 || 10iter: 15.3330 sec.
# イテレーション 3810 || Loss: 4.5729 || 10iter: 15.2664 sec.
# イテレーション 3820 || Loss: 4.7407 || 10iter: 15.1657 sec.
# イテレーション 3830 || Loss: 3.9628 || 10iter: 15.4629 sec.
# イテレーション 3840 || Loss: 4.5530 || 10iter: 15.2965 sec.
# イテレーション 3850 || Loss: 4.4005 || 10iter: 14.9955 sec.
# イテレーション 3860 || Loss: 4.3866 || 10iter: 15.0151 sec.
# イテレーション 3870 || Loss: 4.1001 || 10iter: 15.0687 sec.
# イテレーション 3880 || Loss: 4.3857 || 10iter: 15.1006 sec.
# イテレーション 3890 || Loss: 4.2269 || 10iter: 15.1575 sec.
# イテレーション 3900 || Loss: 4.6347 || 10iter: 15.2866 sec.
# イテレーション 3910 || Loss: 4.4653 || 10iter: 15.4943 sec.
# イテレーション 3920 || Loss: 4.1018 || 10iter: 15.0909 sec.
# イテレーション 3930 || Loss: 3.8554 || 10iter: 15.2056 sec.
# -------------
# epoch 22 || Epoch_TRAIN_Loss:768.7445 ||Epoch_VAL_Loss:0.0000
# timer:  284.1257 sec.
# -------------
# Epoch 23/50
# -------------
# （train）
# イテレーション 3940 || Loss: 4.4275 || 10iter: 2.4966 sec.
# イテレーション 3950 || Loss: 3.7103 || 10iter: 15.2120 sec.
# イテレーション 3960 || Loss: 4.6341 || 10iter: 15.2812 sec.
# イテレーション 3970 || Loss: 4.0017 || 10iter: 15.8422 sec.
# イテレーション 3980 || Loss: 4.4742 || 10iter: 15.9032 sec.
# イテレーション 3990 || Loss: 3.5531 || 10iter: 15.6165 sec.
# イテレーション 4000 || Loss: 4.2429 || 10iter: 15.5774 sec.
# イテレーション 4010 || Loss: 3.7181 || 10iter: 15.5464 sec.
# イテレーション 4020 || Loss: 4.2081 || 10iter: 15.8684 sec.
# イテレーション 4030 || Loss: 4.5478 || 10iter: 15.7719 sec.
# イテレーション 4040 || Loss: 4.4840 || 10iter: 15.3711 sec.
# イテレーション 4050 || Loss: 4.4372 || 10iter: 15.4915 sec.
# イテレーション 4060 || Loss: 4.7735 || 10iter: 15.8626 sec.
# イテレーション 4070 || Loss: 4.4044 || 10iter: 15.9058 sec.
# イテレーション 4080 || Loss: 4.5626 || 10iter: 15.7408 sec.
# イテレーション 4090 || Loss: 4.2916 || 10iter: 15.6433 sec.
# イテレーション 4100 || Loss: 4.1849 || 10iter: 15.8211 sec.
# イテレーション 4110 || Loss: 3.7012 || 10iter: 15.6328 sec.
# -------------
# epoch 23 || Epoch_TRAIN_Loss:764.7301 ||Epoch_VAL_Loss:0.0000
# timer:  291.0951 sec.
# -------------
# Epoch 24/50
# -------------
# （train）
# イテレーション 4120 || Loss: 3.9191 || 10iter: 4.3134 sec.
# イテレーション 4130 || Loss: 4.3766 || 10iter: 15.5021 sec.
# イテレーション 4140 || Loss: 4.3974 || 10iter: 15.2527 sec.
# イテレーション 4150 || Loss: 4.6362 || 10iter: 15.2293 sec.
# イテレーション 4160 || Loss: 4.2003 || 10iter: 15.3218 sec.
# イテレーション 4170 || Loss: 4.3924 || 10iter: 15.1745 sec.
# イテレーション 4180 || Loss: 4.3110 || 10iter: 15.2412 sec.
# イテレーション 4190 || Loss: 4.1993 || 10iter: 15.2546 sec.
# イテレーション 4200 || Loss: 4.1895 || 10iter: 15.2239 sec.
# イテレーション 4210 || Loss: 3.2765 || 10iter: 15.1318 sec.
# イテレーション 4220 || Loss: 4.7531 || 10iter: 15.1895 sec.
# イテレーション 4230 || Loss: 4.0735 || 10iter: 15.3111 sec.
# イテレーション 4240 || Loss: 4.4704 || 10iter: 15.6505 sec.
# イテレーション 4250 || Loss: 3.9568 || 10iter: 15.8256 sec.
# イテレーション 4260 || Loss: 3.7085 || 10iter: 15.4727 sec.
# イテレーション 4270 || Loss: 4.5840 || 10iter: 15.6880 sec.
# イテレーション 4280 || Loss: 4.0883 || 10iter: 15.7650 sec.
# イテレーション 4290 || Loss: 3.9309 || 10iter: 15.7832 sec.
# -------------
# epoch 24 || Epoch_TRAIN_Loss:748.4501 ||Epoch_VAL_Loss:0.0000
# timer:  287.2168 sec.
# -------------
# Epoch 25/50
# -------------
# （train）
# イテレーション 4300 || Loss: 4.8626 || 10iter: 5.7138 sec.
# イテレーション 4310 || Loss: 4.2726 || 10iter: 15.5844 sec.
# イテレーション 4320 || Loss: 4.4018 || 10iter: 15.4272 sec.
# イテレーション 4330 || Loss: 3.9699 || 10iter: 15.1683 sec.
# イテレーション 4340 || Loss: 4.5183 || 10iter: 15.4126 sec.
# イテレーション 4350 || Loss: 3.9590 || 10iter: 14.9372 sec.
# イテレーション 4360 || Loss: 3.7783 || 10iter: 15.1074 sec.
# イテレーション 4370 || Loss: 3.9705 || 10iter: 15.5469 sec.
# イテレーション 4380 || Loss: 4.2571 || 10iter: 15.2916 sec.
# イテレーション 4390 || Loss: 4.1569 || 10iter: 15.2433 sec.
# イテレーション 4400 || Loss: 3.9030 || 10iter: 15.1940 sec.
# イテレーション 4410 || Loss: 3.7236 || 10iter: 15.5906 sec.
# イテレーション 4420 || Loss: 4.3339 || 10iter: 15.0286 sec.
# イテレーション 4430 || Loss: 3.9848 || 10iter: 15.0084 sec.
# イテレーション 4440 || Loss: 3.8040 || 10iter: 15.1452 sec.
# イテレーション 4450 || Loss: 4.0155 || 10iter: 15.5196 sec.
# イテレーション 4460 || Loss: 4.0908 || 10iter: 15.1787 sec.
# イテレーション 4470 || Loss: 4.6145 || 10iter: 15.8971 sec.
# -------------
# epoch 25 || Epoch_TRAIN_Loss:746.7089 ||Epoch_VAL_Loss:0.0000
# timer:  285.3417 sec.
# -------------
# Epoch 26/50
# -------------
# （train）
# イテレーション 4480 || Loss: 3.8471 || 10iter: 7.5502 sec.
# イテレーション 4490 || Loss: 3.6250 || 10iter: 15.8076 sec.
# イテレーション 4500 || Loss: 4.6901 || 10iter: 15.7817 sec.
# イテレーション 4510 || Loss: 4.0938 || 10iter: 15.5905 sec.
# イテレーション 4520 || Loss: 4.3945 || 10iter: 15.3879 sec.
# イテレーション 4530 || Loss: 4.4133 || 10iter: 15.8045 sec.
# イテレーション 4540 || Loss: 4.4392 || 10iter: 15.5211 sec.
# イテレーション 4550 || Loss: 4.2337 || 10iter: 15.4651 sec.
# イテレーション 4560 || Loss: 4.2517 || 10iter: 15.4292 sec.
# イテレーション 4570 || Loss: 4.0442 || 10iter: 15.4198 sec.
# イテレーション 4580 || Loss: 4.1962 || 10iter: 15.4741 sec.
# イテレーション 4590 || Loss: 4.3667 || 10iter: 15.4221 sec.
# イテレーション 4600 || Loss: 4.4991 || 10iter: 15.2824 sec.
# イテレーション 4610 || Loss: 4.4742 || 10iter: 15.3367 sec.
# イテレーション 4620 || Loss: 4.7213 || 10iter: 15.3727 sec.
# イテレーション 4630 || Loss: 4.3561 || 10iter: 15.6217 sec.
# イテレーション 4640 || Loss: 4.3270 || 10iter: 15.3882 sec.
# イテレーション 4650 || Loss: 4.1310 || 10iter: 15.3970 sec.
# -------------
# epoch 26 || Epoch_TRAIN_Loss:740.8624 ||Epoch_VAL_Loss:0.0000
# timer:  288.7022 sec.
# -------------
# Epoch 27/50
# -------------
# （train）
# イテレーション 4660 || Loss: 3.8430 || 10iter: 8.9834 sec.
# イテレーション 4670 || Loss: 4.6712 || 10iter: 15.3668 sec.
# イテレーション 5800 || Loss: 4.0524 || 10iter: 15.3414 sec.
# イテレーション 5810 || Loss: 3.8059 || 10iter: 15.1218 sec.
# イテレーション 5820 || Loss: 3.6019 || 10iter: 15.1395 sec.
# イテレーション 5830 || Loss: 4.0225 || 10iter: 15.0760 sec.
# イテレーション 5840 || Loss: 4.1358 || 10iter: 14.8408 sec.
# イテレーション 5850 || Loss: 3.8338 || 10iter: 14.9720 sec.
# イテレーション 5860 || Loss: 4.0116 || 10iter: 15.3224 sec.
# イテレーション 5870 || Loss: 3.7832 || 10iter: 15.1638 sec.
# イテレーション 5880 || Loss: 3.5211 || 10iter: 15.2858 sec.
# イテレーション 5890 || Loss: 4.3231 || 10iter: 15.1193 sec.
# イテレーション 5900 || Loss: 4.6693 || 10iter: 15.1412 sec.
# -------------
# epoch 33 || Epoch_TRAIN_Loss:683.5025 ||Epoch_VAL_Loss:0.0000
# timer:  282.4180 sec.
# -------------
# Epoch 34/50
# -------------
# （train）
# イテレーション 5910 || Loss: 3.9278 || 10iter: 4.1410 sec.
# イテレーション 5920 || Loss: 3.5938 || 10iter: 14.9183 sec.
# イテレーション 5930 || Loss: 4.0743 || 10iter: 15.1703 sec.
# イテレーション 5940 || Loss: 3.8385 || 10iter: 14.8326 sec.
# イテレーション 5950 || Loss: 4.1713 || 10iter: 15.1593 sec.
# イテレーション 5960 || Loss: 3.7152 || 10iter: 15.0178 sec.
# イテレーション 5970 || Loss: 3.9050 || 10iter: 15.2563 sec.
# イテレーション 5980 || Loss: 4.5194 || 10iter: 15.0613 sec.
# イテレーション 5990 || Loss: 3.8687 || 10iter: 15.0329 sec.
# イテレーション 6000 || Loss: 3.5641 || 10iter: 15.1285 sec.
# イテレーション 6010 || Loss: 3.6424 || 10iter: 15.3218 sec.
# イテレーション 6020 || Loss: 3.6799 || 10iter: 15.3831 sec.
# イテレーション 6030 || Loss: 4.2376 || 10iter: 15.1869 sec.
# イテレーション 6040 || Loss: 4.0587 || 10iter: 15.0393 sec.
# イテレーション 6050 || Loss: 4.2651 || 10iter: 15.0096 sec.
# イテレーション 6060 || Loss: 3.3391 || 10iter: 15.6801 sec.
# イテレーション 6070 || Loss: 3.4460 || 10iter: 15.1765 sec.
# イテレーション 6080 || Loss: 3.7304 || 10iter: 15.2543 sec.
# -------------
# epoch 34 || Epoch_TRAIN_Loss:682.6067 ||Epoch_VAL_Loss:0.0000
# timer:  282.5773 sec.
# -------------
# Epoch 35/50
# -------------
# （train）
# イテレーション 6090 || Loss: 4.1561 || 10iter: 5.6558 sec.
# イテレーション 6100 || Loss: 3.8785 || 10iter: 15.8353 sec.
# イテレーション 6110 || Loss: 3.5707 || 10iter: 15.6930 sec.
# イテレーション 6120 || Loss: 4.0459 || 10iter: 15.5658 sec.
# イテレーション 6130 || Loss: 3.8952 || 10iter: 15.6846 sec.
# イテレーション 6140 || Loss: 3.3357 || 10iter: 15.6705 sec.
# イテレーション 6150 || Loss: 3.5807 || 10iter: 15.1605 sec.
# イテレーション 6160 || Loss: 3.7931 || 10iter: 15.2576 sec.
# イテレーション 6170 || Loss: 3.3724 || 10iter: 15.7478 sec.
# イテレーション 6180 || Loss: 3.9577 || 10iter: 15.4675 sec.
# イテレーション 6190 || Loss: 3.3725 || 10iter: 15.4271 sec.
# イテレーション 6200 || Loss: 4.0968 || 10iter: 15.2051 sec.
# イテレーション 6210 || Loss: 3.8449 || 10iter: 15.4961 sec.
# イテレーション 6220 || Loss: 3.7761 || 10iter: 15.5457 sec.
# イテレーション 6230 || Loss: 3.8820 || 10iter: 14.9869 sec.
# イテレーション 6240 || Loss: 3.5492 || 10iter: 15.1356 sec.
# イテレーション 6250 || Loss: 3.8898 || 10iter: 15.4274 sec.
# イテレーション 6260 || Loss: 3.7163 || 10iter: 15.3182 sec.
# -------------
# epoch 35 || Epoch_TRAIN_Loss:676.6687 ||Epoch_VAL_Loss:0.0000
# timer:  287.5295 sec.
# -------------
# Epoch 36/50
# -------------
# （train）
# イテレーション 6270 || Loss: 3.6946 || 10iter: 7.3990 sec.
# イテレーション 6280 || Loss: 4.0113 || 10iter: 15.1066 sec.
# イテレーション 6290 || Loss: 3.1919 || 10iter: 15.0201 sec.
# イテレーション 6300 || Loss: 3.8461 || 10iter: 14.9380 sec.
# イテレーション 6310 || Loss: 3.9513 || 10iter: 15.2512 sec.
# イテレーション 6320 || Loss: 4.0607 || 10iter: 15.0090 sec.
# イテレーション 6330 || Loss: 2.9682 || 10iter: 15.1620 sec.
# イテレーション 6340 || Loss: 3.4464 || 10iter: 14.9644 sec.
# イテレーション 6350 || Loss: 3.7139 || 10iter: 15.3245 sec.
# イテレーション 6360 || Loss: 4.0400 || 10iter: 15.5622 sec.
# イテレーション 6370 || Loss: 4.0459 || 10iter: 15.2547 sec.
# イテレーション 6380 || Loss: 3.7479 || 10iter: 14.9411 sec.
# イテレーション 6390 || Loss: 4.0724 || 10iter: 15.0213 sec.
# イテレーション 6400 || Loss: 3.8072 || 10iter: 15.3186 sec.
# イテレーション 6410 || Loss: 3.3148 || 10iter: 15.0856 sec.
# イテレーション 6420 || Loss: 3.7294 || 10iter: 14.8815 sec.
# イテレーション 6430 || Loss: 3.5947 || 10iter: 14.7713 sec.
# イテレーション 6440 || Loss: 4.0535 || 10iter: 14.9631 sec.
# -------------
# epoch 36 || Epoch_TRAIN_Loss:669.5551 ||Epoch_VAL_Loss:0.0000
# timer:  281.6025 sec.
# -------------
# Epoch 37/50
# -------------
# （train）
# イテレーション 6450 || Loss: 3.8602 || 10iter: 8.9713 sec.
# イテレーション 6460 || Loss: 3.9049 || 10iter: 14.9074 sec.
# イテレーション 6470 || Loss: 4.0394 || 10iter: 15.4732 sec.
# イテレーション 6480 || Loss: 3.6435 || 10iter: 14.8984 sec.
# イテレーション 6490 || Loss: 3.8881 || 10iter: 14.9279 sec.
# イテレーション 6500 || Loss: 3.5312 || 10iter: 15.0879 sec.
# イテレーション 6510 || Loss: 4.0514 || 10iter: 14.9644 sec.
# イテレーション 6520 || Loss: 3.6376 || 10iter: 15.1000 sec.
# イテレーション 6530 || Loss: 3.3515 || 10iter: 15.2176 sec.
# イテレーション 6540 || Loss: 3.3904 || 10iter: 15.1962 sec.
# イテレーション 6550 || Loss: 3.7961 || 10iter: 14.7724 sec.
# イテレーション 6560 || Loss: 3.6824 || 10iter: 15.0195 sec.
# イテレーション 6570 || Loss: 3.4490 || 10iter: 14.8106 sec.
# イテレーション 6580 || Loss: 3.4490 || 10iter: 15.1341 sec.
# イテレーション 6590 || Loss: 3.5242 || 10iter: 15.0067 sec.
# イテレーション 6600 || Loss: 3.6852 || 10iter: 14.8124 sec.
# イテレーション 6610 || Loss: 3.5386 || 10iter: 15.2349 sec.
# イテレーション 6620 || Loss: 3.4400 || 10iter: 14.9435 sec.
# -------------
# epoch 37 || Epoch_TRAIN_Loss:668.7858 ||Epoch_VAL_Loss:0.0000
# timer:  280.3687 sec.
# -------------
# Epoch 38/50
# -------------
# （train）
# イテレーション 6630 || Loss: 4.0793 || 10iter: 10.4950 sec.
# イテレーション 6640 || Loss: 3.5233 || 10iter: 15.1785 sec.
# イテレーション 6650 || Loss: 3.3024 || 10iter: 15.1452 sec.
# イテレーション 6660 || Loss: 4.2315 || 10iter: 15.1606 sec.
# イテレーション 6670 || Loss: 3.8039 || 10iter: 14.9805 sec.
# イテレーション 6680 || Loss: 3.1703 || 10iter: 14.7712 sec.
# イテレーション 6690 || Loss: 3.9369 || 10iter: 14.9514 sec.
# イテレーション 6700 || Loss: 3.8212 || 10iter: 14.9423 sec.
# イテレーション 6710 || Loss: 3.6930 || 10iter: 15.0116 sec.
# イテレーション 6720 || Loss: 3.7673 || 10iter: 15.0181 sec.
# イテレーション 6730 || Loss: 4.0859 || 10iter: 14.8560 sec.
# イテレーション 6740 || Loss: 3.6090 || 10iter: 15.1106 sec.
# イテレーション 6750 || Loss: 3.3830 || 10iter: 14.9489 sec.
# イテレーション 6760 || Loss: 3.4708 || 10iter: 14.9038 sec.
# イテレーション 6770 || Loss: 3.8390 || 10iter: 14.9771 sec.
# イテレーション 6780 || Loss: 3.8201 || 10iter: 15.0153 sec.
# イテレーション 6790 || Loss: 3.8442 || 10iter: 15.0268 sec.
# イテレーション 6800 || Loss: 3.5977 || 10iter: 14.8247 sec.
# -------------
# epoch 38 || Epoch_TRAIN_Loss:661.9147 ||Epoch_VAL_Loss:0.0000
# timer:  279.8617 sec.
# -------------
# Epoch 39/50
# -------------
# （train）
# イテレーション 6810 || Loss: 3.4977 || 10iter: 11.8542 sec.
# イテレーション 6820 || Loss: 2.9541 || 10iter: 14.7973 sec.
# イテレーション 6830 || Loss: 3.3029 || 10iter: 14.8449 sec.
# イテレーション 6840 || Loss: 3.4939 || 10iter: 14.6094 sec.
# イテレーション 6850 || Loss: 3.7649 || 10iter: 14.7566 sec.
# イテレーション 6860 || Loss: 3.1784 || 10iter: 15.0059 sec.
# イテレーション 6870 || Loss: 3.7222 || 10iter: 15.0642 sec.
# イテレーション 6880 || Loss: 3.8302 || 10iter: 14.8644 sec.
# イテレーション 6890 || Loss: 3.2002 || 10iter: 14.9931 sec.
# イテレーション 6900 || Loss: 3.6121 || 10iter: 15.0312 sec.
# イテレーション 6910 || Loss: 3.8406 || 10iter: 14.8966 sec.
# イテレーション 6920 || Loss: 3.6853 || 10iter: 14.9520 sec.
# イテレーション 6930 || Loss: 4.3783 || 10iter: 15.1490 sec.
# イテレーション 6940 || Loss: 3.2866 || 10iter: 14.7927 sec.
# イテレーション 6950 || Loss: 3.6831 || 10iter: 14.9068 sec.
# イテレーション 6960 || Loss: 4.2846 || 10iter: 14.9742 sec.
# イテレーション 6970 || Loss: 3.9728 || 10iter: 15.0526 sec.
# イテレーション 6980 || Loss: 4.3232 || 10iter: 14.8219 sec.
# -------------
# epoch 39 || Epoch_TRAIN_Loss:655.3753 ||Epoch_VAL_Loss:0.0000
# timer:  278.2563 sec.
# -------------
# Epoch 40/50
# -------------
# （train）
# イテレーション 6990 || Loss: 4.0204 || 10iter: 13.2584 sec.
# イテレーション 7000 || Loss: 3.7956 || 10iter: 15.2809 sec.
# イテレーション 7010 || Loss: 3.7856 || 10iter: 14.8445 sec.
# イテレーション 7020 || Loss: 3.6234 || 10iter: 14.8305 sec.
# イテレーション 7030 || Loss: 4.0639 || 10iter: 14.8775 sec.
# イテレーション 7040 || Loss: 3.5189 || 10iter: 14.8564 sec.
# イテレーション 7050 || Loss: 3.6907 || 10iter: 14.8130 sec.
# イテレーション 7060 || Loss: 3.3572 || 10iter: 14.6941 sec.
# イテレーション 7070 || Loss: 3.6975 || 10iter: 14.8611 sec.
# イテレーション 7080 || Loss: 3.3268 || 10iter: 14.6558 sec.
# イテレーション 7090 || Loss: 3.5399 || 10iter: 14.9944 sec.
# イテレーション 7100 || Loss: 3.5760 || 10iter: 15.0342 sec.
# イテレーション 7110 || Loss: 3.2296 || 10iter: 14.6921 sec.
# イテレーション 7120 || Loss: 3.7196 || 10iter: 14.9489 sec.
# イテレーション 7130 || Loss: 3.2102 || 10iter: 15.0653 sec.
# イテレーション 7140 || Loss: 3.7860 || 10iter: 14.8669 sec.
# イテレーション 7150 || Loss: 3.3141 || 10iter: 14.8172 sec.
# イテレーション 7160 || Loss: 3.6911 || 10iter: 14.8229 sec.
# -------------
# （val）
# -------------
# epoch 40 || Epoch_TRAIN_Loss:654.5617 ||Epoch_VAL_Loss:712.8544
# timer:  387.5667 sec.
# -------------
# Epoch 41/50
# -------------
# （train）
# イテレーション 7170 || Loss: 4.0837 || 10iter: 15.3048 sec.
# イテレーション 7180 || Loss: 3.0772 || 10iter: 14.7636 sec.
# イテレーション 7190 || Loss: 4.0033 || 10iter: 15.0357 sec.
# イテレーション 7200 || Loss: 3.5118 || 10iter: 14.9143 sec.
# イテレーション 7210 || Loss: 3.7147 || 10iter: 14.8689 sec.
# イテレーション 7220 || Loss: 3.6909 || 10iter: 14.8662 sec.
# イテレーション 7230 || Loss: 3.4844 || 10iter: 14.9082 sec.
# イテレーション 7240 || Loss: 3.4428 || 10iter: 14.8534 sec.
# イテレーション 7250 || Loss: 3.4582 || 10iter: 14.7941 sec.
# イテレーション 7260 || Loss: 3.2823 || 10iter: 15.0028 sec.
# イテレーション 7270 || Loss: 3.6242 || 10iter: 15.0610 sec.
# イテレーション 7280 || Loss: 4.0463 || 10iter: 14.9810 sec.
# イテレーション 8030 || Loss: 3.8057 || 10iter: 15.0627 sec.
# イテレーション 8040 || Loss: 3.5101 || 10iter: 15.1319 sec.
# イテレーション 8050 || Loss: 3.7485 || 10iter: 14.9566 sec.
# -------------
# epoch 45 || Epoch_TRAIN_Loss:633.3220 ||Epoch_VAL_Loss:0.0000
# timer:  282.4332 sec.
# -------------
# Epoch 46/50
# -------------
# （train）
# イテレーション 8060 || Loss: 3.4713 || 10iter: 7.1806 sec.
# イテレーション 8070 || Loss: 3.1824 || 10iter: 15.6829 sec.
# イテレーション 8080 || Loss: 3.3502 || 10iter: 15.3717 sec.
# イテレーション 8090 || Loss: 3.5126 || 10iter: 15.0729 sec.
# イテレーション 8100 || Loss: 3.3590 || 10iter: 15.2617 sec.
# イテレーション 8110 || Loss: 3.7519 || 10iter: 15.1191 sec.
# イテレーション 8120 || Loss: 3.5683 || 10iter: 15.2686 sec.
# イテレーション 8130 || Loss: 3.2167 || 10iter: 15.0231 sec.
# イテレーション 8140 || Loss: 3.0543 || 10iter: 15.2815 sec.
# イテレーション 8150 || Loss: 3.3779 || 10iter: 14.9019 sec.
# イテレーション 8160 || Loss: 3.4718 || 10iter: 15.0657 sec.
# イテレーション 8170 || Loss: 3.6697 || 10iter: 15.0355 sec.
# イテレーション 8180 || Loss: 3.8490 || 10iter: 15.2242 sec.
# イテレーション 8190 || Loss: 3.6142 || 10iter: 15.8916 sec.
# イテレーション 8200 || Loss: 3.8419 || 10iter: 15.3886 sec.
# イテレーション 8210 || Loss: 3.6360 || 10iter: 14.9168 sec.
# イテレーション 8220 || Loss: 3.1783 || 10iter: 14.8806 sec.
# イテレーション 8230 || Loss: 3.5806 || 10iter: 15.4368 sec.
# -------------
# epoch 46 || Epoch_TRAIN_Loss:629.4056 ||Epoch_VAL_Loss:0.0000
# timer:  283.7852 sec.
# -------------
# Epoch 47/50
# -------------
# （train）
# イテレーション 8240 || Loss: 3.4396 || 10iter: 8.9488 sec.
# イテレーション 8250 || Loss: 3.6819 || 10iter: 15.6921 sec.
# イテレーション 8260 || Loss: 3.9374 || 10iter: 15.8253 sec.
# イテレーション 8270 || Loss: 4.2163 || 10iter: 15.6853 sec.
# イテレーション 8280 || Loss: 3.5906 || 10iter: 15.8838 sec.
# イテレーション 8290 || Loss: 3.3413 || 10iter: 15.3798 sec.
# イテレーション 8300 || Loss: 3.3708 || 10iter: 15.2709 sec.
# イテレーション 8310 || Loss: 3.7580 || 10iter: 15.5469 sec.
# イテレーション 8320 || Loss: 3.6329 || 10iter: 15.7175 sec.
# イテレーション 8330 || Loss: 3.1670 || 10iter: 15.2051 sec.
# イテレーション 8340 || Loss: 3.4941 || 10iter: 15.3025 sec.
# イテレーション 8350 || Loss: 3.5427 || 10iter: 15.2554 sec.
# イテレーション 8360 || Loss: 2.8205 || 10iter: 15.2357 sec.
# イテレーション 8370 || Loss: 3.5071 || 10iter: 15.2983 sec.
# イテレーション 8380 || Loss: 2.9710 || 10iter: 15.4104 sec.
# イテレーション 8390 || Loss: 3.8542 || 10iter: 15.4183 sec.
# イテレーション 8400 || Loss: 3.7555 || 10iter: 15.1965 sec.
# イテレーション 8410 || Loss: 2.9871 || 10iter: 15.2000 sec.
# -------------
# epoch 47 || Epoch_TRAIN_Loss:619.1358 ||Epoch_VAL_Loss:0.0000
# timer:  287.5037 sec.
# -------------
# Epoch 48/50
# -------------
# （train）
# イテレーション 8420 || Loss: 3.3332 || 10iter: 10.4605 sec.
# イテレーション 8430 || Loss: 3.1328 || 10iter: 14.8327 sec.
# イテレーション 8440 || Loss: 3.6087 || 10iter: 14.9005 sec.
# イテレーション 8450 || Loss: 3.5195 || 10iter: 15.4883 sec.
# イテレーション 8460 || Loss: 3.2282 || 10iter: 15.5352 sec.
# イテレーション 8470 || Loss: 3.7506 || 10iter: 15.1173 sec.
# イテレーション 8480 || Loss: 3.1507 || 10iter: 15.0294 sec.
# イテレーション 8490 || Loss: 2.5840 || 10iter: 15.1142 sec.
# イテレーション 8500 || Loss: 3.7849 || 10iter: 15.3976 sec.
# イテレーション 8510 || Loss: 3.6502 || 10iter: 15.1356 sec.
# イテレーション 8520 || Loss: 2.9059 || 10iter: 15.0391 sec.
# イテレーション 8530 || Loss: 3.4175 || 10iter: 15.3435 sec.
# イテレーション 8540 || Loss: 3.7537 || 10iter: 15.1012 sec.
# イテレーション 8550 || Loss: 3.4896 || 10iter: 15.2966 sec.
# イテレーション 8560 || Loss: 3.8215 || 10iter: 15.4802 sec.
# イテレーション 8570 || Loss: 3.2335 || 10iter: 15.1224 sec.
# イテレーション 8580 || Loss: 2.8557 || 10iter: 15.3052 sec.
# イテレーション 8590 || Loss: 3.9243 || 10iter: 15.1991 sec.
# -------------
# epoch 48 || Epoch_TRAIN_Loss:620.2664 ||Epoch_VAL_Loss:0.0000
# timer:  283.3408 sec.
# -------------
# Epoch 49/50
# -------------
# （train）
# イテレーション 8600 || Loss: 3.3456 || 10iter: 12.0141 sec.
# イテレーション 8610 || Loss: 3.2853 || 10iter: 14.9388 sec.
# イテレーション 8620 || Loss: 3.4530 || 10iter: 14.6262 sec.
# イテレーション 8630 || Loss: 3.6785 || 10iter: 15.1122 sec.
# イテレーション 8640 || Loss: 3.3534 || 10iter: 15.2074 sec.
# イテレーション 8650 || Loss: 3.6126 || 10iter: 14.8719 sec.
# イテレーション 8660 || Loss: 3.0880 || 10iter: 15.1075 sec.
# イテレーション 8670 || Loss: 3.7682 || 10iter: 14.6390 sec.
# イテレーション 8680 || Loss: 2.9481 || 10iter: 15.1503 sec.
# イテレーション 8690 || Loss: 3.2443 || 10iter: 14.9885 sec.
# イテレーション 8700 || Loss: 4.0025 || 10iter: 14.9554 sec.
# イテレーション 8710 || Loss: 3.2469 || 10iter: 14.9125 sec.
# イテレーション 8720 || Loss: 3.1332 || 10iter: 14.9021 sec.
# イテレーション 8730 || Loss: 2.7724 || 10iter: 14.9102 sec.
# イテレーション 8740 || Loss: 3.3171 || 10iter: 15.0614 sec.
# イテレーション 8750 || Loss: 2.9320 || 10iter: 15.0027 sec.
# イテレーション 8760 || Loss: 3.1906 || 10iter: 14.9596 sec.
# イテレーション 8770 || Loss: 2.9161 || 10iter: 14.9061 sec.
# -------------
# epoch 49 || Epoch_TRAIN_Loss:610.6020 ||Epoch_VAL_Loss:0.0000
# timer:  279.1714 sec.
# -------------
# Epoch 50/50
# -------------
# （train）
# イテレーション 8780 || Loss: 3.3617 || 10iter: 13.3990 sec.
# イテレーション 8790 || Loss: 3.1624 || 10iter: 15.1174 sec.
# イテレーション 8800 || Loss: 3.3831 || 10iter: 15.2636 sec.
# イテレーション 8810 || Loss: 3.6708 || 10iter: 15.0835 sec.
# イテレーション 8820 || Loss: 3.2688 || 10iter: 14.8942 sec.
# イテレーション 8830 || Loss: 3.6623 || 10iter: 15.0104 sec.
# イテレーション 8840 || Loss: 2.9770 || 10iter: 14.7660 sec.
# イテレーション 8850 || Loss: 3.5692 || 10iter: 15.0439 sec.
# イテレーション 8860 || Loss: 3.2921 || 10iter: 14.8213 sec.
# イテレーション 8870 || Loss: 3.4651 || 10iter: 14.9481 sec.
# イテレーション 8880 || Loss: 3.3046 || 10iter: 15.1552 sec.
# イテレーション 8890 || Loss: 3.3452 || 10iter: 14.9095 sec.
# イテレーション 8900 || Loss: 2.9847 || 10iter: 14.9600 sec.
# イテレーション 8910 || Loss: 3.2670 || 10iter: 14.9548 sec.
# イテレーション 8920 || Loss: 3.2554 || 10iter: 14.9416 sec.
# イテレーション 8930 || Loss: 3.0457 || 10iter: 14.7808 sec.
# イテレーション 8940 || Loss: 3.3071 || 10iter: 14.8990 sec.
# イテレーション 8950 || Loss: 3.6749 || 10iter: 14.8416 sec.
# -------------
# （val）
# -------------
# epoch 50 || Epoch_TRAIN_Loss:606.7160 ||Epoch_VAL_Loss:686.8110
# timer:  389.4013 sec.
# -------------
# Epoch 51/50
# -------------
# （train）
# イテレーション 8960 || Loss: 3.4198 || 10iter: 14.8315 sec.
# イテレーション 8970 || Loss: 3.2561 || 10iter: 14.8259 sec.
# イテレーション 8980 || Loss: 3.4765 || 10iter: 14.9859 sec.
# イテレーション 8990 || Loss: 3.3690 || 10iter: 15.1732 sec.
# イテレーション 9000 || Loss: 3.4490 || 10iter: 15.0344 sec.
# イテレーション 9010 || Loss: 3.5986 || 10iter: 15.0029 sec.
# イテレーション 9020 || Loss: 3.8089 || 10iter: 15.0060 sec.
# イテレーション 9030 || Loss: 3.2701 || 10iter: 15.0244 sec.
# イテレーション 9040 || Loss: 3.5628 || 10iter: 15.3139 sec.
# イテレーション 9050 || Loss: 2.8001 || 10iter: 15.0661 sec.
# イテレーション 9060 || Loss: 3.0686 || 10iter: 15.0827 sec.
# イテレーション 9070 || Loss: 3.1776 || 10iter: 14.8404 sec.
# イテレーション 9080 || Loss: 3.6818 || 10iter: 14.8452 sec.
# イテレーション 9090 || Loss: 3.5537 || 10iter: 14.9856 sec.
# イテレーション 9100 || Loss: 3.1808 || 10iter: 14.8588 sec.
# イテレーション 9110 || Loss: 3.6774 || 10iter: 15.0916 sec.
# イテレーション 9120 || Loss: 3.0719 || 10iter: 14.9230 sec.
# -------------
# epoch 51 || Epoch_TRAIN_Loss:609.3104 ||Epoch_VAL_Loss:0.0000
# timer:  279.9118 sec.
