# %% [markdown]
# <a href="https://colab.research.google.com/github/pea-sys/Til/blob/master/PyTorch%E6%9C%AC5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.1-2 DCGANの作成
# 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。
#
# # 5.1 学習目標
# Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# DCGANのネットワークを実装できるようになる
# # 5.2 学習目標
# GANの損失関数の形を理解する
# DCGANを実装し、手書き数字画像が生成できる
#
# [写経元](https://github.com/YutaroOgawa/pytorch_advanced/blob/master/5_gan_generation/5-1-2_DCGAN.ipynb)

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます（2分ほど時間がかかります）
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  
# data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %% [markdown]
# # 5.1-2 DCGANの作成
# 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。
#
# # 5.1 学習目標
# * Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# * Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# * GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# * DCGANのネットワークを実装できるようになる
#
# # 5.2 学習目標
# * GANの損失関数の形を理解する
# * DCGANを実装し、手書き数字画像が生成できる

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # 転置畳み込みの例

# %%
input = torch.tensor([[[[1., 1.], [2., 2.]]]])
print("入力データ")
print(input)
print("-----")

print("通常の畳み込み")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))

print("-----")
print("転置畳み込み")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))
# Out:
# 入力データ
# tensor([[[[1., 1.],
#           [2., 2.]]]])
# -----
# 通常の畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[17.]]]], grad_fn=<MkldnnConvolutionBackward>)
# -----
# 転置畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[ 1.,  3.,  2.],
#           [ 5., 13.,  8.],
#           [ 6., 14.,  8.]]]], grad_fn=<SlowConvTranspose2DBackward>)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5014]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # GANの損失関数

# %%
# Dの誤差関数のイメージ実装
# maximize log(D(x)) + log(1 - D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 正解ラベルを作成
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 偽ラベルを作成
label_fake = torch.full((mini_batch_size,), 0)

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 真の画像を判定
d_out_real = D(x)

# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b63842ae8769> in <module>()
#       9
#      10 # 真の画像を判定
# ---> 11 d_out_real = D(x)
#      12
#      13 # 偽の画像を生成して判定
#
# NameError: name 'x' is not defined

# %%
# Gの誤差関数のイメージ実装
# maximize log(D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 200
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/200
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.2401
# timer:  0.9218 sec.
# -------------
# Epoch 1/200
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0176 ||Epoch_G_Loss:0.5050
# timer:  0.5642 sec.
# -------------
# Epoch 2/200
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.6255
# timer:  0.5620 sec.
# -------------
# Epoch 3/200
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1364 ||Epoch_G_Loss:0.0985
# timer:  0.5584 sec.
# -------------
# Epoch 4/200
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0091 ||Epoch_G_Loss:0.4059
# timer:  0.5665 sec.
# -------------
# Epoch 5/200
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0385 ||Epoch_G_Loss:0.6740
# timer:  0.5664 sec.
# -------------
# Epoch 6/200
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.4061 ||Epoch_G_Loss:0.2061
# timer:  0.5653 sec.
# -------------
# Epoch 7/200
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0109 ||Epoch_G_Loss:0.3066
# timer:  0.5672 sec.
# -------------
# Epoch 8/200
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.3755
# timer:  0.5620 sec.
# -------------
# Epoch 9/200
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.2184 ||Epoch_G_Loss:0.3628
# timer:  0.5597 sec.
# -------------
# Epoch 10/200
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0147 ||Epoch_G_Loss:0.2667
# timer:  0.5679 sec.
# -------------
# Epoch 11/200
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.3702
# timer:  0.5700 sec.
# -------------
# Epoch 12/200
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.2411 ||Epoch_G_Loss:0.2569
# timer:  0.5704 sec.
# -------------
# Epoch 13/200
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0345 ||Epoch_G_Loss:0.1875
# timer:  0.5656 sec.
# -------------
# Epoch 14/200
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.1072 ||Epoch_G_Loss:0.2151
# timer:  0.5692 sec.
# -------------
# Epoch 15/200
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0242 ||Epoch_G_Loss:0.2361
# timer:  0.5785 sec.
# -------------
# Epoch 16/200
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.1319 ||Epoch_G_Loss:0.2385
# timer:  0.5676 sec.
# -------------
# Epoch 17/200
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.1980
# timer:  0.5676 sec.
# -------------
# Epoch 18/200
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.2358 ||Epoch_G_Loss:0.2307
# timer:  0.5686 sec.
# -------------
# Epoch 19/200
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.2709
# timer:  0.5668 sec.
# -------------
# Epoch 20/200
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1110 ||Epoch_G_Loss:0.2934
# timer:  0.5676 sec.
# -------------
# Epoch 21/200
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.2801
# timer:  0.5660 sec.
# -------------
# Epoch 22/200
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0312 ||Epoch_G_Loss:0.2641
# timer:  0.5728 sec.
# -------------
# Epoch 23/200
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1950
# timer:  0.5704 sec.
# -------------
# Epoch 24/200
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.2121
# timer:  0.5711 sec.
# -------------
# Epoch 25/200
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.2758
# timer:  0.5705 sec.
# -------------
# Epoch 26/200
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2413
# timer:  0.5670 sec.
# -------------
# Epoch 27/200
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.1223 ||Epoch_G_Loss:0.1356
# timer:  0.5677 sec.
# -------------
# Epoch 28/200
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1822
# timer:  0.5725 sec.
# -------------
# Epoch 29/200
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1901
# timer:  0.5682 sec.
# -------------
# Epoch 30/200
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1102 ||Epoch_G_Loss:0.2105
# timer:  0.5668 sec.
# -------------
# Epoch 31/200
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.2210
# timer:  0.5750 sec.
# -------------
# Epoch 32/200
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1048 ||Epoch_G_Loss:0.1895
# timer:  0.5782 sec.
# -------------
# Epoch 33/200
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0604 ||Epoch_G_Loss:0.2297
# timer:  0.5699 sec.
# -------------
# Epoch 34/200
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1375 ||Epoch_G_Loss:0.2501
# timer:  0.5762 sec.
# -------------
# Epoch 35/200
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1165 ||Epoch_G_Loss:0.1773
# timer:  0.5823 sec.
# -------------
# Epoch 36/200
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1021 ||Epoch_G_Loss:0.2091
# timer:  0.5911 sec.
# -------------
# Epoch 37/200
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0699 ||Epoch_G_Loss:0.2683
# timer:  0.5698 sec.
# -------------
# Epoch 38/200
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1390 ||Epoch_G_Loss:0.1481
# timer:  0.5712 sec.
# -------------
# Epoch 39/200
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1932
# timer:  0.5710 sec.
# -------------
# Epoch 40/200
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.2169
# timer:  0.5786 sec.
# -------------
# Epoch 41/200
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1132 ||Epoch_G_Loss:0.1508
# timer:  0.5722 sec.
# -------------
# Epoch 42/200
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1614
# timer:  0.5764 sec.
# -------------
# Epoch 43/200
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1660
# timer:  0.5802 sec.
# -------------
# Epoch 44/200
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1141 ||Epoch_G_Loss:0.1535
# timer:  0.5906 sec.
# -------------
# Epoch 45/200
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1181 ||Epoch_G_Loss:0.1435
# timer:  0.5728 sec.
# -------------
# Epoch 46/200
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1182 ||Epoch_G_Loss:0.1498
# timer:  0.5777 sec.
# -------------
# Epoch 47/200
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1134 ||Epoch_G_Loss:0.1721
# timer:  0.5741 sec.
# -------------
# Epoch 48/200
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.1522
# timer:  0.5794 sec.
# -------------
# Epoch 49/200
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1374
# timer:  0.5798 sec.
# -------------
# Epoch 50/200
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1330 ||Epoch_G_Loss:0.1813
# timer:  0.5764 sec.
# -------------
# Epoch 51/200
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1224 ||Epoch_G_Loss:0.1156
# timer:  0.5768 sec.
# -------------
# Epoch 52/200
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1446
# timer:  0.5747 sec.
# -------------
# Epoch 53/200
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1059 ||Epoch_G_Loss:0.1474
# timer:  0.5793 sec.
# -------------
# Epoch 54/200
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1139 ||Epoch_G_Loss:0.1393
# timer:  0.5772 sec.
# -------------
# Epoch 55/200
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1673
# timer:  0.5810 sec.
# -------------
# Epoch 56/200
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1387
# timer:  0.5834 sec.
# -------------
# Epoch 57/200
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1196 ||Epoch_G_Loss:0.1682
# timer:  0.5772 sec.
# -------------
# Epoch 58/200
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0929 ||Epoch_G_Loss:0.1492
# timer:  0.5772 sec.
# -------------
# Epoch 59/200
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1041 ||Epoch_G_Loss:0.1766
# timer:  0.5819 sec.
# -------------
# Epoch 60/200
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1629
# timer:  0.5809 sec.
# -------------
# Epoch 61/200
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1014 ||Epoch_G_Loss:0.1734
# timer:  0.5801 sec.
# -------------
# Epoch 62/200
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1027 ||Epoch_G_Loss:0.1672
# timer:  0.5771 sec.
# -------------
# Epoch 63/200
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.1995
# timer:  0.5854 sec.
# -------------
# Epoch 64/200
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1031 ||Epoch_G_Loss:0.1593
# timer:  0.5835 sec.
# -------------
# Epoch 65/200
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0979 ||Epoch_G_Loss:0.1922
# timer:  0.5844 sec.
# -------------
# Epoch 66/200
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1866
# timer:  0.5794 sec.
# -------------
# Epoch 67/200
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.1701
# timer:  0.5812 sec.
# -------------
# Epoch 68/200
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1810
# timer:  0.5874 sec.
# -------------
# Epoch 69/200
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1990
# timer:  0.5837 sec.
# -------------
# Epoch 70/200
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0729 ||Epoch_G_Loss:0.1847
# timer:  0.5901 sec.
# -------------
# Epoch 71/200
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1982
# timer:  0.5927 sec.
# -------------
# Epoch 72/200
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1970
# timer:  0.5831 sec.
# -------------
# Epoch 73/200
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.2146
# timer:  0.5856 sec.
# -------------
# Epoch 74/200
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1743
# timer:  0.5853 sec.
# -------------
# Epoch 75/200
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.2159
# timer:  0.5808 sec.
# -------------
# Epoch 76/200
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1849
# timer:  0.5817 sec.
# -------------
# Epoch 77/200
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1941
# timer:  0.5851 sec.
# -------------
# Epoch 78/200
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0737 ||Epoch_G_Loss:0.1982
# timer:  0.5867 sec.
# -------------
# Epoch 79/200
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0983 ||Epoch_G_Loss:0.2075
# timer:  0.5856 sec.
# -------------
# Epoch 80/200
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0778 ||Epoch_G_Loss:0.2019
# timer:  0.5880 sec.
# -------------
# Epoch 81/200
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0928 ||Epoch_G_Loss:0.2087
# timer:  0.5858 sec.
# -------------
# Epoch 82/200
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0656 ||Epoch_G_Loss:0.2035
# timer:  0.5811 sec.
# -------------
# Epoch 83/200
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.1003 ||Epoch_G_Loss:0.1939
# timer:  0.5816 sec.
# -------------
# Epoch 84/200
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.2012
# timer:  0.5846 sec.
# -------------
# Epoch 85/200
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.2176
# timer:  0.5838 sec.
# -------------
# Epoch 86/200
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0790 ||Epoch_G_Loss:0.1940
# timer:  0.5922 sec.
# -------------
# Epoch 87/200
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.2226
# timer:  0.6014 sec.
# -------------
# Epoch 88/200
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.2058
# timer:  0.5850 sec.
# -------------
# Epoch 89/200
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0745 ||Epoch_G_Loss:0.2429
# timer:  0.5822 sec.
# -------------
# Epoch 90/200
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1505
# timer:  0.5852 sec.
# -------------
# Epoch 91/200
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0843 ||Epoch_G_Loss:0.2200
# timer:  0.5820 sec.
# -------------
# Epoch 92/200
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0838 ||Epoch_G_Loss:0.1944
# timer:  0.5794 sec.
# -------------
# Epoch 93/200
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0795 ||Epoch_G_Loss:0.2083
# timer:  0.5827 sec.
# -------------
# Epoch 94/200
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.2171
# timer:  0.5871 sec.
# -------------
# Epoch 95/200
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.2044
# timer:  0.5835 sec.
# -------------
# Epoch 96/200
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2079
# timer:  0.5934 sec.
# -------------
# Epoch 97/200
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.2223
# timer:  0.5872 sec.
# -------------
# Epoch 98/200
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.2080
# timer:  0.5859 sec.
# -------------
# Epoch 99/200
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.2374
# timer:  0.5837 sec.
# -------------
# Epoch 100/200
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0728 ||Epoch_G_Loss:0.2192
# timer:  0.5918 sec.
# -------------
# Epoch 101/200
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0809 ||Epoch_G_Loss:0.2374
# timer:  0.5865 sec.
# -------------
# Epoch 102/200
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0735 ||Epoch_G_Loss:0.2142
# timer:  0.5877 sec.
# -------------
# Epoch 103/200
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0726 ||Epoch_G_Loss:0.2292
# timer:  0.5930 sec.
# -------------
# Epoch 104/200
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0873 ||Epoch_G_Loss:0.2440
# timer:  0.5954 sec.
# -------------
# Epoch 105/200
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0757 ||Epoch_G_Loss:0.2278
# timer:  0.5939 sec.
# -------------
# Epoch 106/200
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0703 ||Epoch_G_Loss:0.2316
# timer:  0.5918 sec.
# -------------
# Epoch 107/200
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0730 ||Epoch_G_Loss:0.2431
# timer:  0.5929 sec.
# -------------
# Epoch 108/200
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.2297
# timer:  0.5896 sec.
# -------------
# Epoch 109/200
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0690 ||Epoch_G_Loss:0.2749
# timer:  0.5918 sec.
# -------------
# Epoch 110/200
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0752 ||Epoch_G_Loss:0.2294
# timer:  0.5944 sec.
# -------------
# Epoch 111/200
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0623 ||Epoch_G_Loss:0.2540
# timer:  0.5900 sec.
# -------------
# Epoch 112/200
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0938 ||Epoch_G_Loss:0.2220
# timer:  0.5928 sec.
# -------------
# Epoch 113/200
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.2270
# timer:  0.5974 sec.
# -------------
# Epoch 114/200
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.2375
# timer:  0.5908 sec.
# -------------
# Epoch 115/200
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0539 ||Epoch_G_Loss:0.2376
# timer:  0.6043 sec.
# -------------
# Epoch 116/200
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2672
# timer:  0.5933 sec.
# -------------
# Epoch 117/200
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0592 ||Epoch_G_Loss:0.2567
# timer:  0.5886 sec.
# -------------
# Epoch 118/200
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0699 ||Epoch_G_Loss:0.2806
# timer:  0.6021 sec.
# -------------
# Epoch 119/200
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0730 ||Epoch_G_Loss:0.2672
# timer:  0.5916 sec.
# -------------
# Epoch 120/200
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0551 ||Epoch_G_Loss:0.2441
# timer:  0.5950 sec.
# -------------
# Epoch 121/200
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.2582
# timer:  0.5932 sec.
# -------------
# Epoch 122/200
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0731 ||Epoch_G_Loss:0.2441
# timer:  0.5950 sec.
# -------------
# Epoch 123/200
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.2561
# timer:  0.5919 sec.
# -------------
# Epoch 124/200
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2804
# timer:  0.5910 sec.
# -------------
# Epoch 125/200
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2644
# timer:  0.6004 sec.
# -------------
# Epoch 126/200
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2762
# timer:  0.6033 sec.
# -------------
# Epoch 127/200
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0617 ||Epoch_G_Loss:0.2606
# timer:  0.6061 sec.
# -------------
# Epoch 128/200
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.2459
# timer:  0.5989 sec.
# -------------
# Epoch 129/200
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0768 ||Epoch_G_Loss:0.2777
# timer:  0.5958 sec.
# -------------
# Epoch 130/200
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0615 ||Epoch_G_Loss:0.2747
# timer:  0.5977 sec.
# -------------
# Epoch 131/200
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0626 ||Epoch_G_Loss:0.2863
# timer:  0.5937 sec.
# -------------
# Epoch 132/200
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0602 ||Epoch_G_Loss:0.2927
# timer:  0.5975 sec.
# -------------
# Epoch 133/200
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.3095
# timer:  0.5946 sec.
# -------------
# Epoch 134/200
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.2619
# timer:  0.5976 sec.
# -------------
# Epoch 135/200
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0614 ||Epoch_G_Loss:0.2985
# timer:  0.5954 sec.
# -------------
# Epoch 136/200
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0471 ||Epoch_G_Loss:0.2783
# timer:  0.5972 sec.
# -------------
# Epoch 137/200
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.2618
# timer:  0.6031 sec.
# -------------
# Epoch 138/200
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0408 ||Epoch_G_Loss:0.2757
# timer:  0.6279 sec.
# -------------
# Epoch 139/200
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0612 ||Epoch_G_Loss:0.2954
# timer:  0.6049 sec.
# -------------
# Epoch 140/200
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0535 ||Epoch_G_Loss:0.3165
# timer:  0.5972 sec.
# -------------
# Epoch 141/200
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.3332
# timer:  0.5988 sec.
# -------------
# Epoch 142/200
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0612 ||Epoch_G_Loss:0.2607
# timer:  0.6085 sec.
# -------------
# Epoch 143/200
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.3045
# timer:  0.6010 sec.
# -------------
# Epoch 144/200
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.2948
# timer:  0.6010 sec.
# -------------
# Epoch 145/200
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.3114
# timer:  0.6006 sec.
# -------------
# Epoch 146/200
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0429 ||Epoch_G_Loss:0.3371
# timer:  0.6124 sec.
# -------------
# Epoch 147/200
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0571 ||Epoch_G_Loss:0.3112
# timer:  0.5959 sec.
# -------------
# Epoch 148/200
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0553 ||Epoch_G_Loss:0.3485
# timer:  0.6058 sec.
# -------------
# Epoch 149/200
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0425 ||Epoch_G_Loss:0.3235
# timer:  0.5978 sec.
# -------------
# Epoch 150/200
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.3310
# timer:  0.5985 sec.
# -------------
# Epoch 151/200
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.3245
# timer:  0.6060 sec.
# -------------
# Epoch 152/200
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0691 ||Epoch_G_Loss:0.3657
# timer:  0.5968 sec.
# -------------
# Epoch 153/200
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0391 ||Epoch_G_Loss:0.2960
# timer:  0.6022 sec.
# -------------
# Epoch 154/200
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0570 ||Epoch_G_Loss:0.3457
# timer:  0.6048 sec.
# -------------
# Epoch 155/200
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.3068
# timer:  0.5999 sec.
# -------------
# Epoch 156/200
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0565 ||Epoch_G_Loss:0.3343
# timer:  0.6043 sec.
# -------------
# Epoch 157/200
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0667 ||Epoch_G_Loss:0.3747
# timer:  0.5984 sec.
# -------------
# Epoch 158/200
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.3187
# timer:  0.6013 sec.
# -------------
# Epoch 159/200
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0442 ||Epoch_G_Loss:0.3594
# timer:  0.5965 sec.
# -------------
# Epoch 160/200
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.3720
# timer:  0.5986 sec.
# -------------
# Epoch 161/200
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0456 ||Epoch_G_Loss:0.3099
# timer:  0.6000 sec.
# -------------
# Epoch 162/200
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0584 ||Epoch_G_Loss:0.3481
# timer:  0.6083 sec.
# -------------
# Epoch 163/200
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.3493
# timer:  0.6028 sec.
# -------------
# Epoch 164/200
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.3376
# timer:  0.6027 sec.
# -------------
# Epoch 165/200
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0440 ||Epoch_G_Loss:0.3460
# timer:  0.6018 sec.
# -------------
# Epoch 166/200
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0457 ||Epoch_G_Loss:0.3791
# timer:  0.6043 sec.
# -------------
# Epoch 167/200
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0429 ||Epoch_G_Loss:0.3643
# timer:  0.6047 sec.
# -------------
# Epoch 168/200
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0529 ||Epoch_G_Loss:0.3745
# timer:  0.6140 sec.
# -------------
# Epoch 169/200
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0350 ||Epoch_G_Loss:0.3960
# timer:  0.6046 sec.
# -------------
# Epoch 170/200
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0423 ||Epoch_G_Loss:0.3516
# timer:  0.6087 sec.
# -------------
# Epoch 171/200
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.3481
# timer:  0.6255 sec.
# -------------
# Epoch 172/200
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0506 ||Epoch_G_Loss:0.3744
# timer:  0.6112 sec.
# -------------
# Epoch 173/200
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.3594
# timer:  0.6122 sec.
# -------------
# Epoch 174/200
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.3893
# timer:  0.6066 sec.
# -------------
# Epoch 175/200
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.3911
# timer:  0.6024 sec.
# -------------
# Epoch 176/200
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0334 ||Epoch_G_Loss:0.4775
# timer:  0.6058 sec.
# -------------
# Epoch 177/200
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0595 ||Epoch_G_Loss:0.3371
# timer:  0.6073 sec.
# -------------
# Epoch 178/200
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.3971
# timer:  0.6076 sec.
# -------------
# Epoch 179/200
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0387 ||Epoch_G_Loss:0.3981
# timer:  0.6073 sec.
# -------------
# Epoch 180/200
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0404 ||Epoch_G_Loss:0.4162
# timer:  0.6121 sec.
# -------------
# Epoch 181/200
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0274 ||Epoch_G_Loss:0.4131
# timer:  0.6071 sec.
# -------------
# Epoch 182/200
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0535 ||Epoch_G_Loss:0.3913
# timer:  0.6063 sec.
# -------------
# Epoch 183/200
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.4274
# timer:  0.6058 sec.
# -------------
# Epoch 184/200
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0516 ||Epoch_G_Loss:0.3856
# timer:  0.6152 sec.
# -------------
# Epoch 185/200
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0344 ||Epoch_G_Loss:0.4219
# timer:  0.6066 sec.
# -------------
# Epoch 186/200
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0464 ||Epoch_G_Loss:0.4370
# timer:  0.6133 sec.
# -------------
# Epoch 187/200
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0224 ||Epoch_G_Loss:0.4342
# timer:  0.6110 sec.
# -------------
# Epoch 188/200
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.4176
# timer:  0.6116 sec.
# -------------
# Epoch 189/200
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0215 ||Epoch_G_Loss:0.4450
# timer:  0.6166 sec.
# -------------
# Epoch 190/200
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.3838
# timer:  0.6235 sec.
# -------------
# Epoch 191/200
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0267 ||Epoch_G_Loss:0.4759
# timer:  0.6087 sec.
# -------------
# Epoch 192/200
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0355 ||Epoch_G_Loss:0.4020
# timer:  0.6128 sec.
# -------------
# Epoch 193/200
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0405 ||Epoch_G_Loss:0.4672
# timer:  0.6105 sec.
# -------------
# Epoch 194/200
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0240 ||Epoch_G_Loss:0.4439
# timer:  0.6133 sec.
# -------------
# Epoch 195/200
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0323 ||Epoch_G_Loss:0.4244
# timer:  0.6114 sec.
# -------------
# Epoch 196/200
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.4630
# timer:  0.6084 sec.
# -------------
# Epoch 197/200
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0161 ||Epoch_G_Loss:0.4756
# timer:  0.6104 sec.
# -------------
# Epoch 198/200
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0427 ||Epoch_G_Loss:0.4565
# timer:  0.6068 sec.
# -------------
# Epoch 199/200
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0185 ||Epoch_G_Loss:0.4940
# timer:  0.6135 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
