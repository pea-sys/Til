# %% [markdown]
# <a href="https://colab.research.google.com/github/pea-sys/Til/blob/master/PyTorch%E6%9C%AC5_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.4 SAGANの作成¶
# 本ファイルでは、Self-Attention GANのネットワークを実装と学習をします。
#
# # 5.4 学習目標
# * SAGANを実装できるようになる
#
# [写経元](https://github.com/YutaroOgawa/pytorch_advanced/blob/master/5_gan_generation/5-4_SAGAN.ipynb)

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます（2分ほど時間がかかります）
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  
# data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Self-Attentionモジュールの実装

# %%
class Self_Attention(nn.Module):
    """ Self-AttentionのLayer"""

    def __init__(self, in_dim):
        super(Self_Attention, self).__init__()

        # 1×1の畳み込み層によるpointwise convolutionを用意
        self.query_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim, kernel_size=1)

        # Attention Map作成時の規格化のソフトマックス
        self.softmax = nn.Softmax(dim=-2)

        # 元の入力xとSelf-Attention Mapであるoを足し算するときの係数
        # output = x +gamma*o
        # 最初はgamma=0で、学習させていく
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):

        # 入力変数
        X = x

        # 畳み込みをしてから、サイズを変形する。 B,C',W,H→B,C',N へ
        proj_query = self.query_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N
        proj_query = proj_query.permute(0, 2, 1)  # 転置操作
        proj_key = self.key_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N

        # かけ算
        S = torch.bmm(proj_query, proj_key)  # bmmはバッチごとの行列かけ算です

        # 規格化
        attention_map_T = self.softmax(S)  # 行i方向の和を1にするソフトマックス関数
        attention_map = attention_map_T.permute(0, 2, 1)  # 転置をとる

        # Self-Attention Mapを計算する
        proj_value = self.value_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C,N
        o = torch.bmm(proj_value, attention_map.permute(
            0, 2, 1))  # Attention Mapは転置してかけ算

        # Self-Attention MapであるoのテンソルサイズをXにそろえて、出力にする
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x+self.gamma*o

        return out, attention_map

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim, image_size * 8,
                                                      kernel_size=4, stride=1)),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 8, image_size * 4,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 4, image_size * 2,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size * 2)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 2, image_size,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size)

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

        self.self_attntion2 = Self_Attention(in_dim=64)

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images, attention_map1, attention_map2 = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(1, image_size, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size*4)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size*8)

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

# 偽画像をDに入力
d_out, attention_map1, attention_map2 = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.4938]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義 → hinge version of the adversarial lossに変更
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            #label_real = torch.full((mini_batch_size,), 1).to(device)
            #label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real, _, _ = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)

            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # 誤差　d_out_realが1以上で誤差0になる。d_out_real>1で、
            # 1.0 - d_out_realが負の場合ReLUで0にする

            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # 誤差　d_out_fakeが-1以下なら誤差0になる。d_out_fake<-1で、
            # 1.0 + d_out_realが負の場合ReLUで0にする

            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            #g_loss = criterion(d_out_fake.view(-1), label_real)
            g_loss = - d_out_fake.mean()

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    # print("総イテレーション回数:", iteration)

    return G, D

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/300
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0929 ||Epoch_G_Loss:0.1733
# timer:  1.7312 sec.
# -------------
# Epoch 1/300
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.2174 ||Epoch_G_Loss:0.1729
# timer:  1.0804 sec.
# -------------
# Epoch 2/300
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.0951 ||Epoch_G_Loss:0.0210
# timer:  1.0910 sec.
# -------------
# Epoch 3/300
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0578 ||Epoch_G_Loss:0.0979
# timer:  1.0913 sec.
# -------------
# Epoch 4/300
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0000 ||Epoch_G_Loss:0.1167
# timer:  1.0812 sec.
# -------------
# Epoch 5/300
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.1385 ||Epoch_G_Loss:0.0862
# timer:  1.0981 sec.
# -------------
# Epoch 6/300
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.1204
# timer:  1.0841 sec.
# -------------
# Epoch 7/300
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0000 ||Epoch_G_Loss:0.1213
# timer:  1.0828 sec.
# -------------
# Epoch 8/300
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0578 ||Epoch_G_Loss:0.1406
# timer:  1.1068 sec.
# -------------
# Epoch 9/300
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0120 ||Epoch_G_Loss:0.1482
# timer:  1.0810 sec.
# -------------
# Epoch 10/300
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.0724
# timer:  1.0900 sec.
# -------------
# Epoch 11/300
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0268 ||Epoch_G_Loss:0.1312
# timer:  1.0871 sec.
# -------------
# Epoch 12/300
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0472 ||Epoch_G_Loss:0.0980
# timer:  1.0870 sec.
# -------------
# Epoch 13/300
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.1048 ||Epoch_G_Loss:0.1111
# timer:  1.1007 sec.
# -------------
# Epoch 14/300
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.0921
# timer:  1.1082 sec.
# -------------
# Epoch 15/300
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0693 ||Epoch_G_Loss:0.1208
# timer:  1.1039 sec.
# -------------
# Epoch 16/300
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0700 ||Epoch_G_Loss:0.0947
# timer:  1.1023 sec.
# -------------
# Epoch 17/300
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.1182
# timer:  1.1102 sec.
# -------------
# Epoch 18/300
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0707 ||Epoch_G_Loss:0.1007
# timer:  1.1056 sec.
# -------------
# Epoch 19/300
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.1249
# timer:  1.1014 sec.
# -------------
# Epoch 20/300
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.0455
# timer:  1.0988 sec.
# -------------
# Epoch 21/300
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.0732
# timer:  1.1328 sec.
# -------------
# Epoch 22/300
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.0524
# timer:  1.1078 sec.
# -------------
# Epoch 23/300
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.0920
# timer:  1.1180 sec.
# -------------
# Epoch 24/300
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1205 ||Epoch_G_Loss:0.0690
# timer:  1.1091 sec.
# -------------
# Epoch 25/300
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.1297 ||Epoch_G_Loss:0.0748
# timer:  1.1214 sec.
# -------------
# Epoch 26/300
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1427 ||Epoch_G_Loss:0.0651
# timer:  1.1199 sec.
# -------------
# Epoch 27/300
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.1454 ||Epoch_G_Loss:0.0190
# timer:  1.1257 sec.
# -------------
# Epoch 28/300
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1308 ||Epoch_G_Loss:0.0532
# timer:  1.1202 sec.
# -------------
# Epoch 29/300
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1494 ||Epoch_G_Loss:0.1077
# timer:  1.1418 sec.
# -------------
# Epoch 30/300
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1611 ||Epoch_G_Loss:0.0667
# timer:  1.1216 sec.
# -------------
# Epoch 31/300
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1603 ||Epoch_G_Loss:0.0314
# timer:  1.1237 sec.
# -------------
# Epoch 32/300
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1981 ||Epoch_G_Loss:0.0771
# timer:  1.1184 sec.
# -------------
# Epoch 33/300
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1727 ||Epoch_G_Loss:0.0392
# timer:  1.1230 sec.
# -------------
# Epoch 34/300
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1688 ||Epoch_G_Loss:0.0616
# timer:  1.1350 sec.
# -------------
# Epoch 35/300
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1610 ||Epoch_G_Loss:0.0666
# timer:  1.1626 sec.
# -------------
# Epoch 36/300
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1840 ||Epoch_G_Loss:0.0577
# timer:  1.1366 sec.
# -------------
# Epoch 37/300
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1842 ||Epoch_G_Loss:0.0383
# timer:  1.1298 sec.
# -------------
# Epoch 38/300
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1770 ||Epoch_G_Loss:0.0563
# timer:  1.1325 sec.
# -------------
# Epoch 39/300
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.2082 ||Epoch_G_Loss:-0.0049
# timer:  1.1421 sec.
# -------------
# Epoch 40/300
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1758 ||Epoch_G_Loss:0.0487
# timer:  1.1494 sec.
# -------------
# Epoch 41/300
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.2165 ||Epoch_G_Loss:0.0171
# timer:  1.1414 sec.
# -------------
# Epoch 42/300
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.2033 ||Epoch_G_Loss:0.0468
# timer:  1.1432 sec.
# -------------
# Epoch 43/300
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1882 ||Epoch_G_Loss:0.0505
# timer:  1.1378 sec.
# -------------
# Epoch 44/300
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.2033 ||Epoch_G_Loss:0.0085
# timer:  1.1389 sec.
# -------------
# Epoch 45/300
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1966 ||Epoch_G_Loss:0.0519
# timer:  1.1394 sec.
# -------------
# Epoch 46/300
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.2065 ||Epoch_G_Loss:0.0209
# timer:  1.1420 sec.
# -------------
# Epoch 47/300
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1969 ||Epoch_G_Loss:0.0716
# timer:  1.1496 sec.
# -------------
# Epoch 48/300
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.2075 ||Epoch_G_Loss:0.0285
# timer:  1.1514 sec.
# -------------
# Epoch 49/300
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1932 ||Epoch_G_Loss:0.0824
# timer:  1.1487 sec.
# -------------
# Epoch 50/300
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.2023 ||Epoch_G_Loss:-0.0086
# timer:  1.1787 sec.
# -------------
# Epoch 51/300
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.2062 ||Epoch_G_Loss:0.0127
# timer:  1.1619 sec.
# -------------
# Epoch 52/300
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1881 ||Epoch_G_Loss:0.0621
# timer:  1.1692 sec.
# -------------
# Epoch 53/300
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.2116 ||Epoch_G_Loss:0.0118
# timer:  1.1673 sec.
# -------------
# Epoch 54/300
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1877 ||Epoch_G_Loss:0.0284
# timer:  1.1600 sec.
# -------------
# Epoch 55/300
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1671 ||Epoch_G_Loss:0.0827
# timer:  1.1673 sec.
# -------------
# Epoch 56/300
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1934 ||Epoch_G_Loss:-0.0157
# timer:  1.1618 sec.
# -------------
# Epoch 57/300
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1946 ||Epoch_G_Loss:0.0633
# timer:  1.1544 sec.
# -------------
# Epoch 58/300
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1805 ||Epoch_G_Loss:0.0457
# timer:  1.1565 sec.
# -------------
# Epoch 59/300
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1815 ||Epoch_G_Loss:0.0239
# timer:  1.1623 sec.
# -------------
# Epoch 60/300
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1684 ||Epoch_G_Loss:0.0574
# timer:  1.1607 sec.
# -------------
# Epoch 61/300
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1876 ||Epoch_G_Loss:0.0326
# timer:  1.1736 sec.
# -------------
# Epoch 62/300
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1889 ||Epoch_G_Loss:0.0140
# timer:  1.1654 sec.
# -------------
# Epoch 63/300
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1753 ||Epoch_G_Loss:0.0378
# timer:  1.1661 sec.
# -------------
# Epoch 64/300
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1710 ||Epoch_G_Loss:0.0352
# timer:  1.1701 sec.
# -------------
# Epoch 65/300
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1876 ||Epoch_G_Loss:0.0368
# timer:  1.1687 sec.
# -------------
# Epoch 66/300
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1738 ||Epoch_G_Loss:0.0355
# timer:  1.1843 sec.
# -------------
# Epoch 67/300
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1848 ||Epoch_G_Loss:0.0229
# timer:  1.1731 sec.
# -------------
# Epoch 68/300
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1893 ||Epoch_G_Loss:0.0443
# timer:  1.1759 sec.
# -------------
# Epoch 69/300
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1790 ||Epoch_G_Loss:0.0284
# timer:  1.1867 sec.
# -------------
# Epoch 70/300
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.1786 ||Epoch_G_Loss:0.0234
# timer:  1.1774 sec.
# -------------
# Epoch 71/300
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1740 ||Epoch_G_Loss:0.0548
# timer:  1.1820 sec.
# -------------
# Epoch 72/300
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.1822 ||Epoch_G_Loss:0.0475
# timer:  1.1769 sec.
# -------------
# Epoch 73/300
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.1923 ||Epoch_G_Loss:0.0040
# timer:  1.1912 sec.
# -------------
# Epoch 74/300
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1943 ||Epoch_G_Loss:0.0235
# timer:  1.1685 sec.
# -------------
# Epoch 75/300
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.1721 ||Epoch_G_Loss:0.0297
# timer:  1.1769 sec.
# -------------
# Epoch 76/300
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1802 ||Epoch_G_Loss:0.0474
# timer:  1.1807 sec.
# -------------
# Epoch 77/300
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.1829 ||Epoch_G_Loss:0.0456
# timer:  1.1952 sec.
# -------------
# Epoch 78/300
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.1903 ||Epoch_G_Loss:0.0044
# timer:  1.1812 sec.
# -------------
# Epoch 79/300
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.1876 ||Epoch_G_Loss:0.0179
# timer:  1.1851 sec.
# -------------
# Epoch 80/300
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.1798 ||Epoch_G_Loss:0.0312
# timer:  1.1872 sec.
# -------------
# Epoch 81/300
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.1656 ||Epoch_G_Loss:0.0362
# timer:  1.2109 sec.
# -------------
# Epoch 82/300
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.1852 ||Epoch_G_Loss:0.0385
# timer:  1.1939 sec.
# -------------
# Epoch 83/300
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.1939 ||Epoch_G_Loss:0.0298
# timer:  1.1929 sec.
# -------------
# Epoch 84/300
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.1851 ||Epoch_G_Loss:0.0240
# timer:  1.1955 sec.
# -------------
# Epoch 85/300
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.1552 ||Epoch_G_Loss:0.0508
# timer:  1.2103 sec.
# -------------
# Epoch 86/300
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1921 ||Epoch_G_Loss:0.0584
# timer:  1.2225 sec.
# -------------
# Epoch 87/300
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.1735 ||Epoch_G_Loss:0.0250
# timer:  1.2092 sec.
# -------------
# Epoch 88/300
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1770 ||Epoch_G_Loss:0.0412
# timer:  1.2047 sec.
# -------------
# Epoch 89/300
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.1876 ||Epoch_G_Loss:0.0576
# timer:  1.2030 sec.
# -------------
# Epoch 90/300
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.1612 ||Epoch_G_Loss:0.0638
# timer:  1.2139 sec.
# -------------
# Epoch 91/300
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.1816 ||Epoch_G_Loss:0.0297
# timer:  1.2051 sec.
# -------------
# Epoch 92/300
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.1828 ||Epoch_G_Loss:0.0239
# timer:  1.2056 sec.
# -------------
# Epoch 93/300
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.1679 ||Epoch_G_Loss:0.0486
# timer:  1.2098 sec.
# -------------
# Epoch 94/300
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.1724 ||Epoch_G_Loss:0.0275
# timer:  1.2060 sec.
# -------------
# Epoch 95/300
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.1824 ||Epoch_G_Loss:0.0453
# timer:  1.2075 sec.
# -------------
# Epoch 96/300
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.1667 ||Epoch_G_Loss:0.0519
# timer:  1.2129 sec.
# -------------
# Epoch 97/300
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.1757 ||Epoch_G_Loss:0.0525
# timer:  1.2130 sec.
# -------------
# Epoch 98/300
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.1671 ||Epoch_G_Loss:0.0482
# timer:  1.2112 sec.
# -------------
# Epoch 99/300
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.1732 ||Epoch_G_Loss:0.0297
# timer:  1.2083 sec.
# -------------
# Epoch 100/300
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.1665 ||Epoch_G_Loss:0.0216
# timer:  1.2122 sec.
# -------------
# Epoch 101/300
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.1659 ||Epoch_G_Loss:0.0355
# timer:  1.2275 sec.
# -------------
# Epoch 102/300
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.1715 ||Epoch_G_Loss:0.0339
# timer:  1.2147 sec.
# -------------
# Epoch 103/300
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.1623 ||Epoch_G_Loss:0.0428
# timer:  1.2177 sec.
# -------------
# Epoch 104/300
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.1767 ||Epoch_G_Loss:0.0429
# timer:  1.2115 sec.
# -------------
# Epoch 105/300
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.1667 ||Epoch_G_Loss:0.0249
# timer:  1.2133 sec.
# -------------
# Epoch 106/300
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.1663 ||Epoch_G_Loss:0.0639
# timer:  1.2218 sec.
# -------------
# Epoch 107/300
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.1741 ||Epoch_G_Loss:0.0176
# timer:  1.2130 sec.
# -------------
# Epoch 108/300
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.1647 ||Epoch_G_Loss:0.0458
# timer:  1.2131 sec.
# -------------
# Epoch 109/300
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.1686 ||Epoch_G_Loss:0.0594
# timer:  1.2189 sec.
# -------------
# Epoch 110/300
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.1679 ||Epoch_G_Loss:0.0462
# timer:  1.2267 sec.
# -------------
# Epoch 111/300
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.1700 ||Epoch_G_Loss:0.0392
# timer:  1.2336 sec.
# -------------
# Epoch 112/300
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.1595 ||Epoch_G_Loss:0.0311
# timer:  1.2264 sec.
# -------------
# Epoch 113/300
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.1537 ||Epoch_G_Loss:0.0567
# timer:  1.2248 sec.
# -------------
# Epoch 114/300
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.1623 ||Epoch_G_Loss:0.0320
# timer:  1.2363 sec.
# -------------
# Epoch 115/300
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.1441 ||Epoch_G_Loss:0.0450
# timer:  1.2229 sec.
# -------------
# Epoch 116/300
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.1636 ||Epoch_G_Loss:0.0646
# timer:  1.2317 sec.
# -------------
# Epoch 117/300
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.1627 ||Epoch_G_Loss:0.0475
# timer:  1.2274 sec.
# -------------
# Epoch 118/300
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.1599 ||Epoch_G_Loss:0.0283
# timer:  1.2313 sec.
# -------------
# Epoch 119/300
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.1652 ||Epoch_G_Loss:0.0552
# timer:  1.2343 sec.
# -------------
# Epoch 120/300
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.1645 ||Epoch_G_Loss:0.0250
# timer:  1.2215 sec.
# -------------
# Epoch 121/300
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.1541 ||Epoch_G_Loss:0.0587
# timer:  1.2284 sec.
# -------------
# Epoch 122/300
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.1622 ||Epoch_G_Loss:0.0431
# timer:  1.2323 sec.
# -------------
# Epoch 123/300
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.1446 ||Epoch_G_Loss:0.0630
# timer:  1.2274 sec.
# -------------
# Epoch 124/300
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.1526 ||Epoch_G_Loss:0.0399
# timer:  1.2186 sec.
# -------------
# Epoch 125/300
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.1512 ||Epoch_G_Loss:0.0277
# timer:  1.2251 sec.
# -------------
# Epoch 126/300
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.1626 ||Epoch_G_Loss:0.0530
# timer:  1.2262 sec.
# -------------
# Epoch 127/300
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.1632 ||Epoch_G_Loss:0.0509
# timer:  1.2270 sec.
# -------------
# Epoch 128/300
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.1486 ||Epoch_G_Loss:0.0641
# timer:  1.2281 sec.
# -------------
# Epoch 129/300
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.1532 ||Epoch_G_Loss:0.0516
# timer:  1.2225 sec.
# -------------
# Epoch 130/300
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.1519 ||Epoch_G_Loss:0.0441
# timer:  1.2330 sec.
# -------------
# Epoch 131/300
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.1578 ||Epoch_G_Loss:0.0522
# timer:  1.2221 sec.
# -------------
# Epoch 132/300
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.1473 ||Epoch_G_Loss:0.0532
# timer:  1.2257 sec.
# -------------
# Epoch 133/300
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.1482 ||Epoch_G_Loss:0.0506
# timer:  1.2266 sec.
# -------------
# Epoch 134/300
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.1408 ||Epoch_G_Loss:0.0659
# timer:  1.2137 sec.
# -------------
# Epoch 135/300
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.1610 ||Epoch_G_Loss:0.0447
# timer:  1.2375 sec.
# -------------
# Epoch 136/300
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.1525 ||Epoch_G_Loss:0.0716
# timer:  1.2342 sec.
# -------------
# Epoch 137/300
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.1453 ||Epoch_G_Loss:0.0540
# timer:  1.2170 sec.
# -------------
# Epoch 138/300
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.1516 ||Epoch_G_Loss:0.0368
# timer:  1.2075 sec.
# -------------
# Epoch 139/300
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.1346 ||Epoch_G_Loss:0.0491
# timer:  1.2131 sec.
# -------------
# Epoch 140/300
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.1391 ||Epoch_G_Loss:0.0578
# timer:  1.2200 sec.
# -------------
# Epoch 141/300
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.1500 ||Epoch_G_Loss:0.0569
# timer:  1.2152 sec.
# -------------
# Epoch 142/300
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.1427 ||Epoch_G_Loss:0.0732
# timer:  1.2200 sec.
# -------------
# Epoch 143/300
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.1440 ||Epoch_G_Loss:0.0506
# timer:  1.2120 sec.
# -------------
# Epoch 144/300
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.1430 ||Epoch_G_Loss:0.0734
# timer:  1.2112 sec.
# -------------
# Epoch 145/300
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.1416 ||Epoch_G_Loss:0.0664
# timer:  1.2111 sec.
# -------------
# Epoch 146/300
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.1346 ||Epoch_G_Loss:0.0544
# timer:  1.2055 sec.
# -------------
# Epoch 147/300
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.1451 ||Epoch_G_Loss:0.0653
# timer:  1.2171 sec.
# -------------
# Epoch 148/300
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.1379 ||Epoch_G_Loss:0.0709
# timer:  1.2142 sec.
# -------------
# Epoch 149/300
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.1380 ||Epoch_G_Loss:0.0582
# timer:  1.2121 sec.
# -------------
# Epoch 150/300
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.0514
# timer:  1.2247 sec.
# -------------
# Epoch 151/300
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.1394 ||Epoch_G_Loss:0.0678
# timer:  1.2192 sec.
# -------------
# Epoch 152/300
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.1349 ||Epoch_G_Loss:0.0697
# timer:  1.2185 sec.
# -------------
# Epoch 153/300
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.1284 ||Epoch_G_Loss:0.0629
# timer:  1.2013 sec.
# -------------
# Epoch 154/300
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.1398 ||Epoch_G_Loss:0.0689
# timer:  1.2046 sec.
# -------------
# Epoch 155/300
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.1310 ||Epoch_G_Loss:0.0747
# timer:  1.2062 sec.
# -------------
# Epoch 156/300
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.1329 ||Epoch_G_Loss:0.0558
# timer:  1.2006 sec.
# -------------
# Epoch 157/300
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.1270 ||Epoch_G_Loss:0.0744
# timer:  1.2097 sec.
# -------------
# Epoch 158/300
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.1308 ||Epoch_G_Loss:0.0611
# timer:  1.2131 sec.
# -------------
# Epoch 159/300
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.1257 ||Epoch_G_Loss:0.0787
# timer:  1.2100 sec.
# -------------
# Epoch 160/300
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.1250 ||Epoch_G_Loss:0.0631
# timer:  1.2165 sec.
# -------------
# Epoch 161/300
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.1216 ||Epoch_G_Loss:0.0667
# timer:  1.2147 sec.
# -------------
# Epoch 162/300
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.1304 ||Epoch_G_Loss:0.0850
# timer:  1.2043 sec.
# -------------
# Epoch 163/300
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1091
# timer:  1.2014 sec.
# -------------
# Epoch 164/300
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.1360 ||Epoch_G_Loss:0.0519
# timer:  1.2046 sec.
# -------------
# Epoch 165/300
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.1254 ||Epoch_G_Loss:0.0900
# timer:  1.2186 sec.
# -------------
# Epoch 166/300
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.1249 ||Epoch_G_Loss:0.0592
# timer:  1.2192 sec.
# -------------
# Epoch 167/300
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.1175 ||Epoch_G_Loss:0.0929
# timer:  1.2194 sec.
# -------------
# Epoch 168/300
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.1220 ||Epoch_G_Loss:0.0655
# timer:  1.2188 sec.
# -------------
# Epoch 169/300
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.1139 ||Epoch_G_Loss:0.0928
# timer:  1.2121 sec.
# -------------
# Epoch 170/300
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1289 ||Epoch_G_Loss:0.0582
# timer:  1.2227 sec.
# -------------
# Epoch 171/300
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.1238 ||Epoch_G_Loss:0.0814
# timer:  1.2219 sec.
# -------------
# Epoch 172/300
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.0638
# timer:  1.2191 sec.
# -------------
# Epoch 173/300
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.0769
# timer:  1.2136 sec.
# -------------
# Epoch 174/300
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.1208 ||Epoch_G_Loss:0.0881
# timer:  1.2316 sec.
# -------------
# Epoch 175/300
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1167
# timer:  1.2184 sec.
# -------------
# Epoch 176/300
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.1421 ||Epoch_G_Loss:0.0736
# timer:  1.2034 sec.
# -------------
# Epoch 177/300
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.1188 ||Epoch_G_Loss:0.0903
# timer:  1.2223 sec.
# -------------
# Epoch 178/300
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.0752
# timer:  1.2136 sec.
# -------------
# Epoch 179/300
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.1186 ||Epoch_G_Loss:0.0914
# timer:  1.2204 sec.
# -------------
# Epoch 180/300
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.1147 ||Epoch_G_Loss:0.0784
# timer:  1.2226 sec.
# -------------
# Epoch 181/300
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.0928
# timer:  1.2184 sec.
# -------------
# Epoch 182/300
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.0845
# timer:  1.2093 sec.
# -------------
# Epoch 183/300
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.1099 ||Epoch_G_Loss:0.0850
# timer:  1.2142 sec.
# -------------
# Epoch 184/300
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.1115 ||Epoch_G_Loss:0.0882
# timer:  1.2233 sec.
# -------------
# Epoch 185/300
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.1039 ||Epoch_G_Loss:0.0800
# timer:  1.2422 sec.
# -------------
# Epoch 186/300
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.0951
# timer:  1.2131 sec.
# -------------
# Epoch 187/300
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.0990
# timer:  1.2066 sec.
# -------------
# Epoch 188/300
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.0980
# timer:  1.2188 sec.
# -------------
# Epoch 189/300
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.1052 ||Epoch_G_Loss:0.1150
# timer:  1.2126 sec.
# -------------
# Epoch 190/300
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.0815
# timer:  1.2154 sec.
# -------------
# Epoch 191/300
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1076
# timer:  1.2159 sec.
# -------------
# Epoch 192/300
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.0801
# timer:  1.2144 sec.
# -------------
# Epoch 193/300
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1235
# timer:  1.2150 sec.
# -------------
# Epoch 194/300
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.1087 ||Epoch_G_Loss:0.1045
# timer:  1.2045 sec.
# -------------
# Epoch 195/300
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1035
# timer:  1.2207 sec.
# -------------
# Epoch 196/300
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1036
# timer:  1.2168 sec.
# -------------
# Epoch 197/300
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1107
# timer:  1.2189 sec.
# -------------
# Epoch 198/300
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.0926
# timer:  1.2092 sec.
# -------------
# Epoch 199/300
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.1003 ||Epoch_G_Loss:0.1217
# timer:  1.2187 sec.
# -------------
# Epoch 200/300
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0723 ||Epoch_G_Loss:0.1254
# timer:  1.2199 sec.
# -------------
# Epoch 201/300
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.0909
# timer:  1.2120 sec.
# -------------
# Epoch 202/300
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.1166
# timer:  1.2182 sec.
# -------------
# Epoch 203/300
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0817 ||Epoch_G_Loss:0.1107
# timer:  1.2039 sec.
# -------------
# Epoch 204/300
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1019 ||Epoch_G_Loss:0.1312
# timer:  1.2285 sec.
# -------------
# Epoch 205/300
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1237
# timer:  1.2061 sec.
# -------------
# Epoch 206/300
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0936 ||Epoch_G_Loss:0.1345
# timer:  1.2103 sec.
# -------------
# Epoch 207/300
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1096
# timer:  1.2120 sec.
# -------------
# Epoch 208/300
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.1342
# timer:  1.2071 sec.
# -------------
# Epoch 209/300
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1091
# timer:  1.2077 sec.
# -------------
# Epoch 210/300
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1330
# timer:  1.2265 sec.
# -------------
# Epoch 211/300
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0906 ||Epoch_G_Loss:0.1163
# timer:  1.2102 sec.
# -------------
# Epoch 212/300
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.1396
# timer:  1.2020 sec.
# -------------
# Epoch 213/300
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0878 ||Epoch_G_Loss:0.1265
# timer:  1.2096 sec.
# -------------
# Epoch 214/300
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1387
# timer:  1.2119 sec.
# -------------
# Epoch 215/300
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1235
# timer:  1.2217 sec.
# -------------
# Epoch 216/300
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.1417
# timer:  1.2228 sec.
# -------------
# Epoch 217/300
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.1274
# timer:  1.2180 sec.
# -------------
# Epoch 218/300
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.0804 ||Epoch_G_Loss:0.1358
# timer:  1.2121 sec.
# -------------
# Epoch 219/300
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0806 ||Epoch_G_Loss:0.1330
# timer:  1.2062 sec.
# -------------
# Epoch 220/300
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.1514
# timer:  1.2053 sec.
# -------------
# Epoch 221/300
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.1418
# timer:  1.2241 sec.
# -------------
# Epoch 222/300
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.0725 ||Epoch_G_Loss:0.1350
# timer:  1.2028 sec.
# -------------
# Epoch 223/300
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0475 ||Epoch_G_Loss:0.1427
# timer:  1.2001 sec.
# -------------
# Epoch 224/300
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0995 ||Epoch_G_Loss:0.1654
# timer:  1.2052 sec.
# -------------
# Epoch 225/300
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.0602 ||Epoch_G_Loss:0.1498
# timer:  1.2014 sec.
# -------------
# Epoch 226/300
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.1509
# timer:  1.2095 sec.
# -------------
# Epoch 227/300
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0513 ||Epoch_G_Loss:0.1729
# timer:  1.2033 sec.
# -------------
# Epoch 228/300
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1359
# timer:  1.2029 sec.
# -------------
# Epoch 229/300
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.1601
# timer:  1.2249 sec.
# -------------
# Epoch 230/300
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.1425
# timer:  1.2129 sec.
# -------------
# Epoch 231/300
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0688 ||Epoch_G_Loss:0.1518
# timer:  1.2068 sec.
# -------------
# Epoch 232/300
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0552 ||Epoch_G_Loss:0.1412
# timer:  1.2040 sec.
# -------------
# Epoch 233/300
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0695 ||Epoch_G_Loss:0.1482
# timer:  1.1951 sec.
# -------------
# Epoch 234/300
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.1756
# timer:  1.2241 sec.
# -------------
# Epoch 235/300
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0757 ||Epoch_G_Loss:0.1407
# timer:  1.2057 sec.
# -------------
# Epoch 236/300
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.1468
# timer:  1.2076 sec.
# -------------
# Epoch 237/300
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0904 ||Epoch_G_Loss:0.1492
# timer:  1.2117 sec.
# -------------
# Epoch 238/300
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0509 ||Epoch_G_Loss:0.1746
# timer:  1.2030 sec.
# -------------
# Epoch 239/300
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0774 ||Epoch_G_Loss:0.1448
# timer:  1.2083 sec.
# -------------
# Epoch 240/300
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.1817
# timer:  1.2089 sec.
# -------------
# Epoch 241/300
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0611 ||Epoch_G_Loss:0.1644
# timer:  1.2079 sec.
# -------------
# Epoch 242/300
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.1778
# timer:  1.2045 sec.
# -------------
# Epoch 243/300
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0592 ||Epoch_G_Loss:0.1503
# timer:  1.2006 sec.
# -------------
# Epoch 244/300
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0552 ||Epoch_G_Loss:0.1846
# timer:  1.2080 sec.
# -------------
# Epoch 245/300
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0453 ||Epoch_G_Loss:0.1749
# timer:  1.1945 sec.
# -------------
# Epoch 246/300
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0642 ||Epoch_G_Loss:0.1861
# timer:  1.2122 sec.
# -------------
# Epoch 247/300
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.1869
# timer:  1.1932 sec.
# -------------
# Epoch 248/300
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.0456 ||Epoch_G_Loss:0.1519
# timer:  1.1994 sec.
# -------------
# Epoch 249/300
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.1911
# timer:  1.2199 sec.
# -------------
# Epoch 250/300
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.1793
# timer:  1.2072 sec.
# -------------
# Epoch 251/300
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0278 ||Epoch_G_Loss:0.1548
# timer:  1.2055 sec.
# -------------
# Epoch 252/300
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.1982
# timer:  1.1985 sec.
# -------------
# Epoch 253/300
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.1792
# timer:  1.1987 sec.
# -------------
# Epoch 254/300
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.1677
# timer:  1.2062 sec.
# -------------
# Epoch 255/300
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.1747
# timer:  1.2074 sec.
# -------------
# Epoch 256/300
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.1983
# timer:  1.2007 sec.
# -------------
# Epoch 257/300
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0471 ||Epoch_G_Loss:0.1648
# timer:  1.1967 sec.
# -------------
# Epoch 258/300
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.1730
# timer:  1.2084 sec.
# -------------
# Epoch 259/300
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0458 ||Epoch_G_Loss:0.1975
# timer:  1.2139 sec.
# -------------
# Epoch 260/300
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0453 ||Epoch_G_Loss:0.2188
# timer:  1.1998 sec.
# -------------
# Epoch 261/300
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0622 ||Epoch_G_Loss:0.1629
# timer:  1.1938 sec.
# -------------
# Epoch 262/300
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0289 ||Epoch_G_Loss:0.1745
# timer:  1.1971 sec.
# -------------
# Epoch 263/300
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.1991
# timer:  1.1912 sec.
# -------------
# Epoch 264/300
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0456 ||Epoch_G_Loss:0.1949
# timer:  1.2063 sec.
# -------------
# Epoch 265/300
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.2044
# timer:  1.2037 sec.
# -------------
# Epoch 266/300
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.1970
# timer:  1.2021 sec.
# -------------
# Epoch 267/300
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0513 ||Epoch_G_Loss:0.2013
# timer:  1.1970 sec.
# -------------
# Epoch 268/300
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0547 ||Epoch_G_Loss:0.1967
# timer:  1.1907 sec.
# -------------
# Epoch 269/300
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0507 ||Epoch_G_Loss:0.1924
# timer:  1.1964 sec.
# -------------
# Epoch 270/300
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0391 ||Epoch_G_Loss:0.1868
# timer:  1.1958 sec.
# -------------
# Epoch 271/300
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.1807
# timer:  1.2143 sec.
# -------------
# Epoch 272/300
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.2121
# timer:  1.1924 sec.
# -------------
# Epoch 273/300
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0389 ||Epoch_G_Loss:0.1887
# timer:  1.2138 sec.
# -------------
# Epoch 274/300
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.1958
# timer:  1.2146 sec.
# -------------
# Epoch 275/300
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0471 ||Epoch_G_Loss:0.2077
# timer:  1.2055 sec.
# -------------
# Epoch 276/300
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.2014
# timer:  1.1961 sec.
# -------------
# Epoch 277/300
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0337 ||Epoch_G_Loss:0.2009
# timer:  1.1917 sec.
# -------------
# Epoch 278/300
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.0565 ||Epoch_G_Loss:0.2175
# timer:  1.2037 sec.
# -------------
# Epoch 279/300
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0377 ||Epoch_G_Loss:0.1961
# timer:  1.2050 sec.
# -------------
# Epoch 280/300
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.2167
# timer:  1.2027 sec.
# -------------
# Epoch 281/300
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0363 ||Epoch_G_Loss:0.2062
# timer:  1.1912 sec.
# -------------
# Epoch 282/300
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0458 ||Epoch_G_Loss:0.2386
# timer:  1.2062 sec.
# -------------
# Epoch 283/300
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0317 ||Epoch_G_Loss:0.1980
# timer:  1.1949 sec.
# -------------
# Epoch 284/300
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0517 ||Epoch_G_Loss:0.2148
# timer:  1.2258 sec.
# -------------
# Epoch 285/300
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0442 ||Epoch_G_Loss:0.2254
# timer:  1.2017 sec.
# -------------
# Epoch 286/300
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0447 ||Epoch_G_Loss:0.2425
# timer:  1.1902 sec.
# -------------
# Epoch 287/300
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.1949
# timer:  1.1905 sec.
# -------------
# Epoch 288/300
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0408 ||Epoch_G_Loss:0.2680
# timer:  1.1968 sec.
# -------------
# Epoch 289/300
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0432 ||Epoch_G_Loss:0.2097
# timer:  1.1990 sec.
# -------------
# Epoch 290/300
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0194 ||Epoch_G_Loss:0.2077
# timer:  1.1951 sec.
# -------------
# Epoch 291/300
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2152
# timer:  1.2072 sec.
# -------------
# Epoch 292/300
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.2250
# timer:  1.2050 sec.
# -------------
# Epoch 293/300
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0404 ||Epoch_G_Loss:0.2255
# timer:  1.2031 sec.
# -------------
# Epoch 294/300
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.2379
# timer:  1.1993 sec.
# -------------
# Epoch 295/300
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.2356
# timer:  1.1919 sec.
# -------------
# Epoch 296/300
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0565 ||Epoch_G_Loss:0.2012
# timer:  1.1904 sec.
# -------------
# Epoch 297/300
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0374 ||Epoch_G_Loss:0.2406
# timer:  1.1970 sec.
# -------------
# Epoch 298/300
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0422 ||Epoch_G_Loss:0.2042
# timer:  1.2001 sec.
# -------------
# Epoch 299/300
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0274 ||Epoch_G_Loss:0.2287
# timer:  1.2065 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは、良い感じの画像が生成されるまで、何度か実行をし直しています

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
fake_images, am1, am2 = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# Attentiom Mapを出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):

    # 上段に生成した画像データを
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

    # 下段にAttentin Map1の画像中央のピクセルのデータを
    plt.subplot(2, 5, 5+i+1)
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7]  # 中央に着目
    plt.imshow(am.cpu().detach().numpy(), 'Reds')
